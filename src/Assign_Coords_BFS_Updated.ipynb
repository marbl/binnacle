# %%
import numpy as np
import pandas as pd
import networkx as nx
from os import listdir
from copy import deepcopy
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.backends.backend_pdf import PdfPages

rcParams = {'font.size': 17 , 'font.weight': 'normal', 'font.family': 'sans-serif',
            'axes.unicode_minus':False, 'axes.labelweight':'normal'}

graphspath = 'Mount-2/MetaCarvel_paper/hmp_scaffolds/stool/'
covpath = 'Research-Activities/Data/genomecov_d/'#'Mount-2/projects/refining_bins_with_assembly_graphs/genomecov_d/'
op_path = 'Scaffold_Coverage_After_Delinking/'

# %% [markdown]
# <h2>Computing Global Coordinates</h2>
# <ol>
#     <li>This function computes the global coordinate system for the scaffold(connected component) based on the length of the contigs in the connected component and the linking information as returned by MetaCarvel. We order the contigs based on the topological sort of the subgraph and assign coordinates in the global coorinate system in breadth first manner.</li>
#     <li>We also consider the contig orientations and the edge orientations in accurate estimation of coordinates. </li>
#     <li>If there multiple possible assignments we pick the one that has the largest coordinate value. We choose the greedy approaach because the number of solutions grows exponentially and the problem is NP-Hard! </li>
#     <li>Finally, we normalize all other positions based on the least cooridnate value so that the coorinate system starts with 0.</li>
#     <li>The input to the program is the connected component subgraph of the assembly graph ``oriented.gml" which is a result of running MetaCarvel.</li>
# </ol>

# %%
def Compute_Global_Coordinates(subgraph):
    if not nx.is_directed_acyclic_graph(subgraph):
        return []
    top_sort = list(nx.topological_sort(subgraph))
    v_0 = top_sort[0]
    v_0_orientation = subgraph.nodes[v_0]['orientation']
    v_0_length = int(subgraph.nodes[v_0]['length'])
    if v_0_orientation == 'FOW':
        start = 0
        end = start + v_0_length
    elif v_0_orientation == 'REV':
        start = 0
        end = start-v_0_length
    global_coords = {v_0 : (start,end)}
    visited = dict(zip(top_sort, [False]*len(top_sort)))
    Q = [v_0]
    g_undir = subgraph.to_undirected()
    
    while len(Q) > 0:
        src = Q.pop()
        visited[src] = True
        neighbors = g_undir.neighbors(src)
        for n in neighbors:
            if subgraph.has_edge(src,n):
                ###Estimate n's coordinates based on the conting ordering src,n
                edge = (src, n)
                edge_orientation = subgraph.edges[edge]['orientation']
                edge_overlap = int(float(g_undir.edges[edge]['mean']))
                c2_length = int(g_undir.nodes[n]['length'])
                s1, e1 = global_coords[src]
                if edge_orientation == 'EE':
                    e2 = e1 + edge_overlap
                    s2 = e2 + c2_length
                if edge_orientation == 'EB':
                    s2 = e1 + edge_overlap
                    e2 = s2 + c2_length
                if edge_orientation == 'BB':
                    s2 = s1 + edge_overlap
                    e2 = s2 + c2_length
                if edge_orientation == 'BE':
                    e2 = s1 + edge_overlap
                    s2 = e2 + c2_length
                start,end = (s2, e2)
            else:
                ###Estimate n's coordinates based on the conting ordering n,src
                edge = (n,src)
                edge_orientation = subgraph.edges[edge]['orientation']
                edge_overlap = int(float(g_undir.edges[edge]['mean']))
                c1_length = int(g_undir.nodes[n]['length'])
                s2, e2 = global_coords[src]
                if edge_orientation == 'EE':
                    e1 = e2 - edge_overlap
                    s1 = e1 - c1_length
                if edge_orientation == 'EB':
                    e1 = s2 - edge_overlap
                    s1 = e1 - c1_length
                if edge_orientation == 'BB':
                    s1 = s2 - edge_overlap
                    e1 = s1 - c1_length
                if edge_orientation == 'BE':
                    s1 = e2 - edge_overlap
                    e1 = s1 - c1_length
                start,end = (s1,e1)
            try:
                if global_coords[n][0] < start:
                    global_coords[n] = (start,end)
            except KeyError:
                global_coords[n] = (start,end)
            if visited[n] == False:
                visited[n] = True
                Q.append(n)
    ###Normalize for the global coordinate system to start from 0
    min_coord = np.inf
    for g in global_coords:
        start,end = global_coords[g]
        min_val = min(start,end)
        if min_val < min_coord:
            min_coord = min_val
    for g in global_coords:
        s,e = global_coords[g]
        global_coords[g] = s-min_coord, e-min_coord
    return global_coords

# %% [markdown]
# <h2> Computing Coverages </h2>
#
# To compute the read coverages we use the *genomecov* program, part of the *bedtools* suite. We run *genomecov* with *-d* optional enabled so that we get the per base depth. The output of the prgram is utilized to compute the depth along the scaffold and this function loads the out of genomecov as a dataframe.

# %%
def Load_Read_Coverage(sample):
    df_coverage = pd.read_csv(covpath+sample+'.txt',names = ['Contig','Loc','coverage'], 
                              sep = '\t', low_memory = False,  
                              dtype = {'Contig': str, 'Loc': np.int32, 'Coverage': np.int32},
                              index_col = 'Contig', engine='c')
    df_coverage['Loc'] = df_coverage['Loc']-1
    return df_coverage

# %% [markdown]
# <h2> Computing the Depth of Coverage along the Scaffold's Global Coordinate System  </h2>
#
# To compute the depth we run the *Compute_Global_Coordinates* and *Load_Read_Coverage* functions and pass this to the *Compute_Coverage* described below. This program estimates the per cooridnate depth by using the outputs of the said two information. The program returns the coverage along the entire scaffold and the coverage along the longest path and a dataframe contiaining the contig, its average depth and its coordinates in the scaffold.

# %%
def Compute_Coverage(connected_component, df_coverage):
    top_sort = list(nx.topological_sort(connected_component))
    coords = Compute_Global_Coordinates(connected_component)
    max_coord = -np.inf
    for c in top_sort:
        max_v = max(coords[c])
        if max_v >= max_coord: max_coord = max_v
    coverage = np.zeros(max_coord+1)
    d_arr = []
    for c in top_sort:
        contig_depth = np.array(df_coverage.loc[c]['coverage'])
        d = {'Contig':c, 'Average_Depth':np.median(contig_depth),'Coords':coords[c]}
        d_arr.append(d)
        s,e = coords[c]
        if (s > e): coverage[s:e:-1] += contig_depth[::-1]
        else: coverage[s:e] += contig_depth
    df_depths = pd.DataFrame(d_arr)
    df_depths = df_depths.set_index('Contig')
    df_depths = df_depths.loc[top_sort]
    longest_coverage = np.zeros(max_coord+1)
    longest_path = list(nx.dag_longest_path(connected_component))
    for c in longest_path:
        contig_depth = np.array(df_coverage.loc[c]['coverage'])
        s,e = coords[c]
        if (s > e): longest_coverage[s:e:-1] += contig_depth[::-1]
        else: longest_coverage[s:e] += contig_depth
    return coverage, longest_coverage, df_depths

# %% [markdown]
# <h2> Change Point Detection on the Scaffold Coverage </h2>
#
# To compute changepoints along the scaffold we slide a window of default size 1500 along the scaffold and take the ratios of the maximum of means of the window preceeding any point and the window suceeding the point and the minimum of the said quantities. Any abnromal spike magnitude indicates a change point. If the size of the contig is less than the size of the window we adaptively pick a smaller window.

# %%
def Helper_Changepoints(cov_vec, window_size = 1500):
    indices_non_zero = np.where(cov_vec > 0)
    sliced = cov_vec[indices_non_zero]
    while window_size >= len(sliced)/2:
        window_size = int(window_size/5)
        print(window_size)
    m = []
    for i in range(window_size, len(sliced)-window_size):
        pred = sliced[i-window_size:i].mean()
        succ = sliced[i:i+window_size].mean()
        if pred == 0 or succ == 0: 
            r = 0
        else: 
            r = max(pred,succ)/min(pred,succ)
        m.append(r)
        
    mean_ratios = [0]*window_size + m + [0]*window_size
    cpts = np.zeros(len(cov_vec))
    cpts[indices_non_zero] = mean_ratios
    return cpts

# %% [markdown]
# <h2> Outlier Detection in Change Point Signals </h2>
# <ol>
#     <li>The following code segment is used to identify outliers in change points. To do so, we compute the peaks first.</li>
#     <li>We don't directly identify outliers on the signal because doing so would pickup points near the peaks, these are indicators of sliding windows and not really outliers.</li>
#     <li>To overcome the issue, we first identify peaks. A point is a peak if a point is larger than its predecessor and successor. This is performed by the function *ID_Peaks*.</li>
#     <li>The output of this passed to *ID_outliers* which picks all those points that is gretaer than the point which is the *thresh*'s percentile. The default value of *thresh* is 98.5. </li>
#     <li>The filter outliers is still a work in progress. This is aimed at removing all the outliers points that is close to one another, but this is not super important. While the mthod described in the following block is data driven we are working on improving this method by examining the underlying graph structure.</li>
# </ol>

# %%
def ID_outliers(change_point_vec, thresh):
    cutoff = np.percentile(change_point_vec, thresh)
    indices = np.where(change_point_vec >= cutoff)
    return indices

def ID_Peaks(change_point_vec, thresh = 98.5):
    indices = range(0, len(change_point_vec))
    Peak_Indices = []
    for i in range(1,len(indices)-1):
        prev_index, curr_index, next_index = indices[i-1], indices[i], indices[i+1]
        pt1, pt2, pt3 = change_point_vec[prev_index], change_point_vec[curr_index], change_point_vec[next_index]
        if max(pt1, pt2, pt3) == pt2 and pt2 > 0: Peak_Indices.append(curr_index)
    Peak_Indices = np.array(Peak_Indices)
    Peak_Values = change_point_vec[Peak_Indices]
    outlier_peaks = ID_outliers(Peak_Values, thresh)
    return Peak_Indices[outlier_peaks]#filtered_outliers

def Filter_Neighbors(outlier_list, changepoints, window_size = 100):
    if len(outlier_list) == 0:
        print(outlier_list)
        return outlier_list
    filtered_outlier_list = []
    i = 0
    cmp = outlier_list[0]
    outlier_set = set({cmp})
    for i in range(1, len(outlier_list)):
        curr = outlier_list[i]
        if (curr - cmp) <= window_size:
            if changepoints[curr] >= changepoints[cmp]:
                outlier_set.remove(cmp)
                outlier_set.update([curr])
                cmp = curr
            else:
                outlier_set.update([cmp])
        else:
            outlier_set.update([curr])
            cmp = curr
    outlier_set = list(outlier_set)
    outlier_set.sort()
    return outlier_set

# %% [markdown]
# <h2> Rules for delinking contigs at change points. </h2>
#
# The rules for delinking the contigs are described below. The first row represent the orientation of the contig and the first colum represent the location of the contig relative to the contig at the change point.
#
# |#                   |  Forward            |  Reverse          |
# |:------------------:|---------------------|-------------------|
# |        Start       | Delink predecessor  | Delink successor  |
# |          End       | Delink successor    | Delink predecessor|
#
# The input to the program is the set of outliers, the dictionary containing the contigs at each position, a vector of means for detecting change points and a *pos_cutoff* that specifies the number of basepairs from the contig ends to considered for delinking.

# %%
def Get_Outlier_Contigs(outliers, positions, coordinates, graph, pos_cutoff = 100):
    g_ = deepcopy(graph)
    potential_contigs_removal = {}
    for o in outliers:
        contigs_intersecting = positions[o]
        closest_contig, closest_contig_val = '',np.inf
        forward, start = True, True
        for contig in contigs_intersecting:
            s,e = coordinates[contig]
            if s>e: f = False
            else: f = True
                
            if np.abs(s-o) < closest_contig_val:
                closest_contig_val= np.abs(s-o) 
                closest_contig = contig
                forward = f
            if np.abs(e-o) < closest_contig_val:
                closest_contig_val= np.abs(e-o) 
                closest_contig = contig
                forward = f
                start = False
        if closest_contig_val <= pos_cutoff:
            potential_contigs_removal[closest_contig] = (closest_contig_val, o, forward, start)
    
    for c in potential_contigs_removal:
        p = potential_contigs_removal[c]
        #print(c,p)
        fwd, start = p[2], p[3]       
        if(fwd == True) and (start == True): 
            print('Removing',c,'\'s Predecessors')
            predecessors = list(g_.predecessors(str(c)))
            if len(predecessors) > 0:
                edges = [(pred,c) for pred in predecessors]
                g_.remove_edges_from(edges)
        if(fwd == False) and (start == True): 
            print('Removing',c,'\'s Successors')
            successors = list(g_.successors(str(c)))
            if len(successors) > 0:
                edges = [(c,succ) for succ in successors]
                g_.remove_edges_from(edges)
        if(fwd == False) and (start == False): 
            print('Removing',c,'\'s Predecessors')
            predecessors = list(g_.predecessors(str(c)))
            if len(predecessors) > 0:
                edges = [(pred,c) for pred in predecessors]
                g_.remove_edges_from(edges)
        if(fwd == True) and (start == False): 
            print('Removing',c,'\'s Successors')
            successors = list(g_.successors(str(c)))
            if len(successors) > 0:
                edges = [(c,succ) for succ in successors]
                g_.remove_edges_from(edges)
    return g_

# %% [markdown]
# <h2> Visualize the Results </h2>
#
# In this code fragment we plot two figures, one describing
# <ol>
#     <li>The Pileup of Contigs</li>
#     <li>Coverages along the global Coordinate </li>
#     <li>Change Point Metric </li>
#     <li>The Coverages of the Various Contigs in the Scaffold</li>
#     The program calls the methods above to perform the computations.
# </ol>
#
# The second figure plots the coverage of a contig with respect to its predecessors and successors.

# %%
def Return_Contig_Scaffold_Positions(coordinate_dictionary):
    pos_dict = {}
    for c in coordinate_dictionary:
        start, end = coordinate_dictionary[c]
        if start > end: a,b = end, start
        else: a,b = start,end
        for i in range(a, b+1):
            try: pos_dict[i].append(c)
            except KeyError: pos_dict[i] = [c]
    return pos_dict


def Write_Coverage_Outputs(graph,df_coverage):
    weakly_connected_components = list(nx.weakly_connected_component_subgraphs(graph))
    cc_ctr = 0
    list_coverages = []
    list_coords = []
    for i in range(len(weakly_connected_components)):
        test = weakly_connected_components[i]
        if nx.is_directed_acyclic_graph(test):
            print(i, len(test.nodes()))
            nodes = list(test.nodes())
            df_coverage_cc = df_coverage.loc[nodes]
            coverage, longest_coverage, df_depths = Compute_Coverage(test, df_coverage_cc)
            mean_ratios = Helper_Changepoints(deepcopy(coverage))
            outliers = ID_Peaks(mean_ratios)
            outliers = Filter_Neighbors(outliers, mean_ratios)
    
            top_sort = df_depths.index.tolist()
            coords = dict(zip(df_depths.index.tolist(), df_depths['Coords'].tolist()))
            Pos_Dict = Return_Contig_Scaffold_Positions(coords)
            df_depths = df_depths.loc[top_sort]

            g_removed = Get_Outlier_Contigs(outliers, Pos_Dict, coords, test, 100)
            delinked_conn_comps = list(nx.weakly_connected_component_subgraphs(g_removed))
            
            for cc in delinked_conn_comps:
                cc_ctr += 1
                coverage_cc, longest_coverage_cc, df_depths_cc = Compute_Coverage(cc, df_coverage_cc)
                coords_cc = dict(zip(df_depths_cc.index.tolist(), df_depths_cc['Coords'].tolist()))
                for i in range(len(coverage_cc)):
                    d = {'Connected_Component':cc_ctr, 'Coordinates':i,'Coverage':coverage_cc[i]}
                    list_coverages.append(d)
                for c in coords_cc:
                    d = {'Connected_Component':cc_ctr, 'Contig':c, 
                         'Start':coords_cc[c][0],'End':coords_cc[c][1]}
                    list_coords.append(d)
        print('\n')
    df_coords = pd.DataFrame(list_coords)
    df_coords = df_coords.sort_values(by = ['Connected_Component'])
    
    df_coverages_scaffolds = pd.DataFrame(list_coverages)
    df_coverages_scaffolds = df_coverages_scaffolds.sort_values(by = ['Connected_Component','Coordinates'])
    
    return df_coords, df_coverages_scaffolds

def Draw_Plots(connected_component, title, df_coverage):
    coverage, longest_coverage, df_depths = Compute_Coverage(connected_component, df_coverage)
    mean_ratios = Helper_Changepoints(deepcopy(coverage))
    outliers = ID_Peaks(mean_ratios)
    outliers = Filter_Neighbors(outliers, mean_ratios)
    
    top_sort = df_depths.index.tolist()
    coords = dict(zip(df_depths.index.tolist(), df_depths['Coords'].tolist()))
    Pos_Dict = Return_Contig_Scaffold_Positions(coords)
    df_depths = df_depths.loc[top_sort]
    
    contigs_set_outliers = set({})
    for o in outliers:
        contigs = Pos_Dict[o]
        contigs_set_outliers.update(contigs)
    contigs_set_outliers = list(contigs_set_outliers)
    
    fig_line_chart, ax_line_chart = plt.subplots(4, 1, figsize=(20, 40),
                    gridspec_kw={'height_ratios': [2.75 ,0.75, 0.75, 0.75]})
    ctr, ctr_inc  = 0.5, 0.5
    yticks, ytick_labels = [ctr], []
    for k in top_sort:
        start,end = coords[k]
        if start > end: color = 'red'
        else: color = 'blue'
        if k in contigs_set_outliers: color = 'green'
        ax_line_chart[0].plot([start, end],[ctr, ctr], linewidth = 3, color = color)
        ax_line_chart[0].axhline(ctr, color = 'black', linewidth=0.5)
        ctr += ctr_inc
        yticks.append(ctr)
        ytick_labels.append(k)
    ax_line_chart[0].set_yticks(yticks)
    colors = ['red', 'blue', 'green']
    lines = [Line2D([0], [0], color=c, linewidth=3) for c in colors]
    labels = ['Reverse', 'Forward','Outlier']
    ax_line_chart[0].legend(lines, labels)
    ax_line_chart[0].set_yticklabels(ytick_labels)
    #ax_line_chart[0].set_xlim([14000, 22000])
    
    ax_line_chart[1].plot(coverage, color = 'teal', label = 'Scaffold Coverage')
    ax_line_chart[1].plot(longest_coverage, color = 'orange', label = 'Longest Path Coverage')
    ax_line_chart[1].set_xlabel('Scaffold Coordinate')
    ax_line_chart[1].set_ylabel('Fold Coverage')
    ax_line_chart[1].legend()
    
    ax_line_chart[2].plot(mean_ratios, color = 'brown', linewidth = 2)
    ax_line_chart[2].set_ylabel('Change Points')
    for o in outliers:
        ax_line_chart[0].axvline(o, color = 'black', linewidth = 0.8, linestyle = '--')
        ax_line_chart[1].axvline(o, color = 'black', linewidth = 0.8, linestyle = '--')
        ax_line_chart[2].axvline(o, color = 'black', linewidth = 0.8, linestyle = '--')
    outliers.sort()
    temp = [0]+list(outliers)+[len(coverage)]
    for i in range(len(temp)-1): 
        if i%2 == 0: c = 'pink'
        else: c = 'black'
        ax_line_chart[0].axvspan(temp[i], temp[i+1], alpha=0.3, color=c)
        ax_line_chart[1].axvspan(temp[i], temp[i+1], alpha=0.3, color=c)
        ax_line_chart[2].axvspan(temp[i], temp[i+1], alpha=0.3, color=c)

    outlier_bars = []
    for i in range(0, len(top_sort)):
        if top_sort[i] in contigs_set_outliers:
            outlier_bars.append(i)
            
    bars = ax_line_chart[3].bar(df_depths.index, df_depths['Average_Depth'], color = 'green')
    ax_line_chart[3].set_xticklabels(df_depths.index, rotation=90)#, ha='right')
    for b in outlier_bars:
         bars[b].set_color('r')
    ax_line_chart[3].set_ylabel('Median Coverage')
    fig_line_chart.suptitle(title)
    fig_line_chart.tight_layout()
    fig_line_chart.subplots_adjust(top=0.97, left = 0.15)
    
    fig_depth_scatter, ax_depth_scatter = plt.subplots(2,1,figsize=(20,12), gridspec_kw={'height_ratios': [2,1]})
    pos, depth_ratio = 0, []
    for c in coords:
        depths_pred = list(df_depths.loc[list(connected_component.predecessors(c))]['Average_Depth'])
        depths_succ = list(df_depths.loc[list(connected_component.successors(c))]['Average_Depth'])
        x_pred = [pos for i in range(len(depths_pred))]
        x_succ = [pos for i in range(len(depths_succ))]
        ax_depth_scatter[0].scatter(x_pred, depths_pred, color = 'blue', marker = 'x')
        ax_depth_scatter[0].scatter(x_succ, depths_succ, color = 'olive', marker = '<')
        depth = df_depths.loc[c]['Average_Depth']
        depths = depths_pred+depths_succ
        depth_ratio.append(depth/max(depths))
        if max(depths) < depth and len(depths) > 2:
            ax_depth_scatter[0].scatter(pos, depth, color = 'black', s = 150, facecolors='none', linewidth = 3)
        ax_depth_scatter[0].scatter(pos, depth, color = 'red', s = 80, alpha = 0.6)
        ax_depth_scatter[0].axvline(pos, linewidth = 0.3, linestyle = '--', color = 'black')
        ax_depth_scatter[1].axvline(pos, linewidth = 0.3, linestyle = '--', color = 'black')
        pos += 1
    ax_depth_scatter[0].set_xticks([])
    
    ax_depth_scatter[1].plot(range(0, len(top_sort)), depth_ratio, marker = 'o', color = 'blue')
    ax_depth_scatter[1].set_xticks(range(0, len(top_sort)))
    ax_depth_scatter[1].set_xticklabels(top_sort, rotation = 90)
    ax_depth_scatter[1].axhline(1, color = 'black')
    
    fig_depth_scatter.suptitle(title)
    fig_depth_scatter.tight_layout()
    fig_depth_scatter.subplots_adjust(top=0.94, bottom = 0.25)
    
    g_removed = Get_Outlier_Contigs(outliers, Pos_Dict, coords, connected_component, 100)
    conns = list(nx.weakly_connected_component_subgraphs(g_removed))
    fig_removed, ax_removed = plt.subplots(len(conns),1, figsize = (20,40), 
                                          gridspec_kw={'height_ratios': [1.0/len(conns)]*len(conns)})

    for i in range(len(conns)):
        conn = conns[i]
        coverage, longest_coverage, df_depths = Compute_Coverage(conn, df_coverage)
        if len(conns) > 1:
            ax_removed[i].plot(coverage, color = 'red',label = 'Scaffold coverage')
            ax_removed[i].plot(longest_coverage, color = 'blue', label = 'Longest Path Coverage')
            ax_removed[i].legend()
            ax_removed[i].set_title('Number of Contigs:'+str(len(conn)))
        else:
            ax_removed.plot(coverage, color = 'red',label = 'Scaffold coverage')
            ax_removed.plot(longest_coverage, color = 'blue', label = 'Longest Path Coverage')
            ax_removed.legend()
            ax_removed.set_title('Number of Contigs:'+str(len(conn)))
    fig_removed.tight_layout()
    fig_removed.suptitle(title)
    fig_removed.subplots_adjust(top=0.94)
    
    return fig_line_chart, fig_depth_scatter, fig_removed

# %%
samples = listdir(covpath)
samples.sort()
plt.rcParams.update(rcParams)
#samples = ['SRS019397']

# %% [markdown]
# This part of the code just calls the "Draw_Plots" codes. This calls the various above methods. These are the various variables to look out for,
# <ol>
#     <li>coverage = Scaffold level coverage</li>
#     <li>longest_coverage = Coverage along the longest path</li>
#     <li>mean_ratios = The ratios used to detect change points </li>
#     <li>outliers = Outliers detected on the change point signal </li>
#     <li>coords = The dictionary with the contigs as the keys and coordinates as the value</li>
#     <li>Pos_Dict = This dictionary gives the contig ids at every position along the scaffold</li>
# </ol>
#
# Return whichever variable you want for your analysis.
#
# If you want to run for a particular sample set that to the sample, you dont have to iterate through all the samples.
#
# Similarly just mention the connected component id you are interested in viewing the plot for the second loop. For an example the connected component we are looking at now is connected component id 16 in my machine. This could be different in various machines. We are looking at a scaffold with 73 contigs and the sample id is 'SRS012902.txt'.

# %%
for s in samples[6:]:
    sample = s.replace(".txt","")
    if sample[0] == '.':
        continue
    print(s)
    Graph_path= graphspath+sample+'/'+sample+'_scaffolds/oriented.gml'
    G = nx.read_gml(Graph_path)
    weakly_connected_components = list(nx.weakly_connected_component_subgraphs(G))
    df_coverage =Load_Read_Coverage(sample) 
    
    pdf_1 = PdfPages(op_path+sample+'.pdf')
    
    for i in range(len(weakly_connected_components)):
        test = weakly_connected_components[i]
        if len(test) >= 3 and nx.is_directed_acyclic_graph(test):
            nodes = list(test.nodes())
            coverage = df_coverage.loc[nodes]
            fig1, fig2, fig3 = Draw_Plots(test, 'Connected Component:'+str(i), coverage)
            pdf_1.savefig( fig1 )
            pdf_1.savefig( fig2 )
            pdf_1.savefig( fig3 )
            plt.close('all')
            print(i, len(weakly_connected_components))
            
    pdf_1.close()
# Out:
# SRS013215.txt
# 1 692
# Removing 1003 's Successors
# 2 692
# Removing 2280 's Successors
# Removing 237 's Successors
# 4 692
# Removing 75 's Predecessors
# Removing 777 's Successors
# 6 692
# Removing 823 's Predecessors
# Removing 1016 's Successors
# Removing 472 's Successors
# 8 692
# 9 692
# Removing 1483 's Successors
# Removing 1688 's Predecessors
# Removing contig-100_5043.5043 's Predecessors
# Removing 1018 's Predecessors
# 10 692
# Removing 1019 's Predecessors
# 11 692
# 12 692
# Removing 153 's Predecessors
# Removing 1063 's Predecessors
# Removing contig-100_1989.19623 's Successors
# Removing 457 's Predecessors
# Removing 1029 's Successors
# Removing contig-100_2606.20240 's Successors
# Removing 161 's Successors
# 15 692
# Removing 820 's Successors
# 18 692
# Removing 1108 's Predecessors
# Removing contig-100_5452.5452 's Predecessors
# Removing contig-100_680.18314 's Successors
# Removing contig-100_481.18115 's Successors
# 20 692
# Removing 1134 's Predecessors
# Removing contig-100_3235.20869 's Successors
# 21 692
# Removing 1044 's Predecessors
# Removing contig-100_1527.23408 's Successors
# 22 692
# Removing contig-100_971.18605 's Predecessors
# 25 692
# 26 692
# Removing contig-100_1299.23180 's Successors
# 27 692
# 28 692
# 34 692
# Removing contig-100_9177.9177 's Predecessors
# 35 692
# Removing 1222 's Successors
# Removing 1094 's Successors
# Removing 425 's Successors
# Removing contig-100_398.22279 's Predecessors
# Removing 1311 's Predecessors
# Removing contig-100_50.21931 's Predecessors
# Removing 1089 's Predecessors
# Removing 465 's Successors
# Removing 261 's Successors
# Removing 2236 's Successors
# 37 692
# Removing contig-100_3571.21205 's Predecessors
# 39 692
# 42 692
# Removing 1939 's Successors
# 43 692
# Removing 1110 's Successors
# 45 692
# 46 692
# Removing 885 's Predecessors
# Removing 1107 's Predecessors
# 47 692
# 48 692
# Removing 1475 's Predecessors
# Removing contig-100_1386.1386 's Successors
# 51 692
# 52 692
# 53 692
# 62 692
# Removing 2063 's Predecessors
# Removing 1152 's Successors
# 65 692
# Removing contig-100_2962.20596 's Predecessors
# Removing contig-100_5491.5491 's Successors
# 68 692
# Removing 979 's Successors
# Removing 178 's Successors
# Removing contig-100_1484.1484 's Successors
# Removing 1963 's Successors
# Removing 1295 's Successors
# 69 692
# 71 692
# 77 692
# Removing contig-100_90.21971 's Predecessors
# Removing contig-100_744.22625 's Successors
# 78 692
# 79 692
# 82 692
# Removing contig-100_1413.19047 's Predecessors
# Removing 631 's Predecessors
# Removing 2311 's Successors
# 89 692
# 90 692
# 91 692
# 92 692
# Removing 2358 's Successors
# 94 692
# Removing 1218 's Predecessors
# 95 692
# Removing contig-100_8119.8119 's Predecessors
# Removing 377 's Successors
# 97 692
# 99 692
# Removing 134 's Predecessors
# Removing 1321 's Predecessors
# Removing 123 's Successors
# Removing 1845 's Successors
# 101 692
# Removing contig-100_1425.19059 's Successors
# 103 692
# 106 692
# Removing 1248 's Predecessors
# 107 692
# Removing contig-100_1861.23742 's Predecessors
# 108 692
# 109 692
# Removing contig-100_1470.23351 's Successors
# 111 692
# Removing 67 's Predecessors
# Removing contig-100_1663.19297 's Predecessors
# 113 692
# Removing 876 's Successors
# Removing contig-100_278.17912 's Successors
# Removing 1271 's Successors
# Removing 798 's Predecessors
# Removing 1461 's Successors
# Removing 383 's Successors
# 115 692
# 116 692
# Removing 1281 's Successors
# 117 692
# Removing 1283 's Successors
# Removing contig-100_1925.23806 's Predecessors
# 118 692
# 120 692
# Removing 2188 's Predecessors
# 125 692
# Removing contig-100_1945.19579 's Predecessors
# 127 692
# Removing 880 's Predecessors
# Removing 1314 's Predecessors
# 128 692
# Removing 680 's Successors
# Removing 658 's Successors
# 129 692
# Removing 527 's Successors
# 130 692
# Removing 886 's Successors
# 132 692
# 300
# Removing 1368 's Predecessors
# 134 692
# 135 692
# Removing 1330 's Successors
# 137 692
# 138 692
# 139 692
# Removing 1337 's Successors
# 140 692
# Removing 1952 's Successors
# 141 692
# Removing 1347 's Successors
# 143 692
# Removing contig-100_284.24378 's Successors
# 147 692
# Removing contig-100_3226.20860 's Successors
# 149 692
# Removing 1374 's Successors
# 150 692
# Removing 1436 's Predecessors
# Removing contig-100_1371.23252 's Predecessors
# 151 692
# 152 692
# Removing contig-100_1752.23633 's Predecessors
# Removing 1561 's Successors
# 153 692
# Removing 2171 's Successors
# Removing 2268 's Predecessors
# Removing 2305 's Successors
# 155 692
# 162 692
# 164 692
# Removing 37 's Predecessors
# Removing 2141 's Predecessors
# 165 692
# Removing 1502 's Predecessors
# Removing 2239 's Predecessors
# Removing 1649 's Successors
# Removing 906 's Successors
# Removing 1683 's Successors
# Removing 757 's Successors
# Removing 1639 's Successors
# Removing 1769 's Successors
# Removing 1841 's Successors
# 166 692
# 168 692
# 170 692
# 172 692
# Removing 1429 's Successors
# 173 692
# Removing 1919 's Successors
# Removing contig-100_2072.19706 's Predecessors
# 179 692
# 300
# 180 692
# 181 692
# Removing 1737 's Successors
# Removing contig-100_2286.19920 's Successors
# Removing 2293 's Predecessors
# 182 692
# Removing contig-100_5059.5059 's Predecessors
# 183 692
# 184 692
# Removing contig-100_5156.5156 's Successors
# 185 692
# 186 692
# Removing 824 's Successors
# 187 692
# 188 692
# 189 692
# 190 692
# Removing 1725 's Successors
# 191 692
# 197 692
# Removing 853 's Successors
# 199 692
# 201 692
# 204 692
# Removing 1532 's Successors
# Removing 1986 's Successors
# 205 692
# Removing 1791 's Successors
# Removing 2276 's Successors
# Removing 214 's Successors
# 207 692
# Removing contig-100_3614.21248 's Predecessors
# 211 692
# Removing 255 's Successors
# 214 692
# 215 692
# Removing contig-100_7382.7382 's Predecessors
# Removing contig-100_2771.20405 's Predecessors
# Removing contig-100_219.22100 's Successors
# 217 692
# 218 692
# Removing contig-100_658.18292 's Successors
# 221 692
# 223 692
# Removing contig-100_7934.7934 's Successors
# 224 692
# Removing contig-100_7693.7693 's Successors
# 226 692
# Removing 491 's Predecessors
# Removing contig-100_444.18078 's Successors
# 227 692
# Removing contig-100_52.24146 's Successors
# Removing contig-100_68.24162 's Successors
# Removing contig-100_9168.9168 's Successors
# 229 692
# 231 692
# 234 692
# Removing 2027 's Successors
# 235 692
# 300
# Removing 1657 's Predecessors
# 236 692
# Removing 1666 's Successors
# 239 692
# 240 692
# 243 692
# Removing contig-100_114.21995 's Predecessors
# Removing 1710 's Successors
# 249 692
# 252 692
# Removing 2353 's Successors
# 256 692
# Removing 1745 's Predecessors
# Removing contig-100_73.24167 's Successors
# 258 692
# 266 692
# 275 692
# Removing 2180 's Successors
# 276 692
# Removing 2284 's Successors
# 277 692
# Removing 1959 's Successors
# 279 692
# Removing contig-100_2812.20446 's Successors
# 284 692
# Removing contig-100_1703.23584 's Successors
# 286 692
# Removing contig-100_6710.6710 's Successors
# 290 692
# 297 692
# Removing contig-100_1263.23144 's Successors
# 298 692
# 299 692
# 300 692
# 302 692
# Removing contig-100_167.17801 's Predecessors
# Removing 2324 's Successors
# 303 692
# 306 692
# Removing 620 's Successors
# 307 692
# 308 692
# 310 692
# 315 692
# 316 692
# Removing contig-100_2619.20253 's Predecessors
# 322 692
# 328 692
# Removing 2080 's Successors
# 329 692
# Removing 901 's Successors
# 330 692
# Removing 2155 's Successors
# 332 692
# Removing 2370 's Predecessors
# Removing contig-100_157.24251 's Successors
# 338 692
# Removing 311 's Successors
# 345 692
# 346 692
# Removing 851 's Predecessors
# 354 692
# Removing contig-100_7799.7799 's Predecessors
# 355 692
# 357 692
# 360 692
# Removing 2232 's Successors
# 361 692
# 367 692
# 368 692
# Removing contig-100_1720.23601 's Predecessors
# 369 692
# 371 692
# 376 692
# 388 692
# 391 692
# Removing contig-100_357.357 's Successors
# 401 692
# 409 692
# Removing contig-100_619.18253 's Successors
# Removing 696 's Successors
# 414 692
# Removing contig-100_2978.2978 's Predecessors
# 419 692
# 422 692
# Removing contig-100_2575.20209 's Predecessors
# 423 692
# Removing contig-100_3303.3303 's Predecessors
# 427 692
# 442 692
# Removing 731 's Successors
# 444 692
# 449 692
# 460 692
# 475 692
# 479 692
# 480 692
# 488 692
# Removing contig-100_1498.23379 's Successors
# 490 692
# 493 692
# 495 692
# 496 692
# 518 692
# 524 692
# 526 692
# 528 692
# 530 692
# 568 692
# 300
# 596 692
# 300
# 600 692
# 614 692
# 300
# Removing contig-100_3959.3959 's Successors
# 620 692
# 643 692
# SRS016438.txt
# Removing 2562 's Successors
# Removing 3867 's Successors
# 0 1342
# 1 1342
# Removing 1007 's Predecessors
# 2 1342
# Removing 1658 's Predecessors
# Removing contig-100_1808.1808 's Successors
# 5 1342
# 7 1342
# Removing 5386 's Successors
# Removing 932 's Successors
# Removing 6323 's Successors
# 8 1342
# Removing contig-100_10283.39600 's Predecessors
# Removing 315 's Successors
# 9 1342
# Removing 647 's Predecessors
# Removing 6306 's Predecessors
# Removing contig-100_10941.40258 's Successors
# Removing 5921 's Successors
# Removing 1036 's Successors
# Removing 6517 's Successors
# 10 1342
# Removing 2728 's Successors
# Removing 1038 's Successors
# 11 1342
# Removing 5693 's Successors
# Removing 1655 's Successors
# 12 1342
# Removing contig-100_1991.50948 's Predecessors
# 15 1342
# 16 1342
# Removing 5571 's Successors
# 17 1342
# 18 1342
# Removing 5945 's Predecessors
# Removing 5962 's Successors
# 19 1342
# Removing 1821 's Predecessors
# Removing 1234 's Successors
# Removing contig-100_1982.31299 's Successors
# 20 1342
# 21 1342
# Removing 1623 's Successors
# Removing 1061 's Successors
# 22 1342
# Removing 3466 's Successors
# Removing 1065 's Predecessors
# 23 1342
# Removing 1074 's Predecessors
# 25 1342
# Removing 1078 's Successors
# Removing 2104 's Successors
# Removing contig-100_1838.55171 's Successors
# 26 1342
# Removing 6746 's Successors
# 27 1342
# 28 1342
# 29 1342
# Removing 2669 's Successors
# 30 1342
# Removing 548 's Successors
# Removing 7227 's Successors
# 31 1342
# Removing 2614 's Predecessors
# Removing 3138 's Predecessors
# Removing 5722 's Successors
# Removing contig-100_7018.36335 's Successors
# 32 1342
# Removing 6090 's Predecessors
# Removing 6060 's Predecessors
# Removing contig-100_3450.52407 's Successors
# 34 1342
# Removing contig-100_9048.38365 's Predecessors
# Removing 391 's Predecessors
# 35 1342
# Removing 5415 's Predecessors
# Removing 6651 's Predecessors
# 37 1342
# Removing 1718 's Successors
# 40 1342
# Removing 1121 's Successors
# 41 1342
# 43 1342
# 44 1342
# 46 1342
# Removing contig-100_2711.51668 's Predecessors
# Removing 1133 's Predecessors
# Removing 1169 's Successors
# Removing 3407 's Predecessors
# 48 1342
# Removing 1136 's Successors
# 49 1342
# 52 1342
# Removing 6878 's Successors
# Removing contig-100_4356.46332 's Predecessors
# Removing contig-100_5337.34654 's Predecessors
# 54 1342
# Removing contig-100_10234.39551 's Successors
# 55 1342
# Removing 2687 's Successors
# 59 1342
# Removing contig-100_3138.32455 's Successors
# 60 1342
# Removing 1166 's Predecessors
# Removing 759 's Successors
# 61 1342
# 62 1342
# 64 1342
# 65 1342
# Removing 1176 's Successors
# 66 1342
# 68 1342
# Removing contig-100_4445.33762 's Successors
# Removing 607 's Successors
# 70 1342
# Removing 1184 's Predecessors
# 71 1342
# 72 1342
# 73 1342
# 75 1342
# Removing 2237 's Successors
# Removing 6020 's Successors
# 76 1342
# Removing 5998 's Predecessors
# 77 1342
# 78 1342
# Removing 1645 's Successors
# Removing contig-100_4090.4090 's Successors
# 79 1342
# Removing 6317 's Predecessors
# 81 1342
# Removing 3629 's Successors
# Removing 4698 's Successors
# Removing 653 's Successors
# 82 1342
# Removing 4268 's Successors
# Removing 7031 's Successors
# 83 1342
# 84 1342
# Removing 1227 's Successors
# Removing 2989 's Predecessors
# Removing 7241 's Successors
# 85 1342
# Removing contig-100_5765.5765 's Predecessors
# 87 1342
# Removing 2697 's Successors
# 88 1342
# Removing contig-100_48.48 's Successors
# 89 1342
# Removing 3280 's Predecessors
# Removing contig-100_2482.44458 's Predecessors
# 92 1342
# Removing 2910 's Predecessors
# Removing contig-100_2980.44956 's Successors
# 94 1342
# Removing 1259 's Predecessors
# 95 1342
# Removing 748 's Successors
# 96 1342
# Removing 1954 's Predecessors
# Removing 1272 's Successors
# 99 1342
# Removing contig-100_5508.47484 's Predecessors
# Removing 2328 's Predecessors
# Removing 1273 's Predecessors
# 100 1342
# Removing 4150 's Predecessors
# Removing 403 's Successors
# Removing 1398 's Predecessors
# Removing 6013 's Successors
# 101 1342
# Removing 4954 's Predecessors
# 104 1342
# Removing 5940 's Successors
# Removing 1288 's Successors
# Removing 3271 's Successors
# 105 1342
# Removing 1290 's Successors
# 106 1342
# Removing 6147 's Predecessors
# 107 1342
# 109 1342
# Removing 2787 's Successors
# Removing 4448 's Successors
# 110 1342
# 111 1342
# 112 1342
# Removing 1308 's Predecessors
# 113 1342
# 115 1342
# Removing 7023 's Successors
# Removing 3325 's Successors
# 116 1342
# 117 1342
# 118 1342
# Removing 7089 's Successors
# 119 1342
# Removing contig-100_1545.50502 's Predecessors
# 120 1342
# 122 1342
# Removing contig-100_504.53837 's Successors
# Removing 6087 's Successors
# Removing 404 's Predecessors
# Removing 2043 's Successors
# Removing 5453 's Successors
# 123 1342
# 124 1342
# 125 1342
# 127 1342
# Removing 1359 's Successors
# 130 1342
# Removing contig-100_882.42858 's Successors
# Removing 3556 's Predecessors
# Removing 1361 's Predecessors
# 131 1342
# 133 1342
# Removing contig-100_5912.47888 's Predecessors
# 136 1342
# Removing 364 's Successors
# Removing 6830 's Successors
# Removing 3789 's Successors
# 137 1342
# Removing contig-100_10591.39908 's Predecessors
# 138 1342
# Removing 141 's Successors
# Removing 2903 's Predecessors
# 139 1342
# Removing 216 's Successors
# Removing 527 's Successors
# 140 1342
# Removing 1641 's Successors
# Removing 5919 's Successors
# 141 1342
# Removing 6292 's Predecessors
# Removing contig-100_915.54248 's Successors
# Removing contig-100_493.53826 's Predecessors
# 143 1342
# 144 1342
# Removing 2065 's Predecessors
# Removing 566 's Successors
# 145 1342
# Removing 5993 's Successors
# Removing 800 's Predecessors
# 147 1342
# Removing contig-100_2864.51821 's Predecessors
# Removing 4923 's Predecessors
# 149 1342
# Removing contig-100_854.54187 's Successors
# 150 1342
# Removing 333 's Predecessors
# 151 1342
# 152 1342
# Removing contig-100_2523.51480 's Successors
# Removing 7148 's Successors
# 154 1342
# Removing 6268 's Predecessors
# Removing 2153 's Successors
# 156 1342
# 160 1342
# Removing 2290 's Successors
# 161 1342
# Removing 6765 's Predecessors
# 163 1342
# 300
# Removing 3430 's Successors
# 164 1342
# Removing contig-100_2884.51841 's Predecessors
# Removing 3824 's Predecessors
# 165 1342
# Removing 3010 's Successors
# 167 1342
# 168 1342
# 300
# 169 1342
# 170 1342
# 172 1342
# Removing 1632 's Successors
# 173 1342
# 174 1342
# Removing contig-100_649.29966 's Successors
# 175 1342
# 176 1342
# Removing 5883 's Predecessors
# 177 1342
# Removing contig-100_1614.54947 's Successors
# 179 1342
# 182 1342
# Removing contig-100_2340.51297 's Predecessors
# Removing 1660 's Successors
# 186 1342
# Removing 1589 's Successors
# 187 1342
# Removing 159 's Predecessors
# 188 1342
# Removing 3943 's Predecessors
# Removing 5096 's Successors
# 189 1342
# 193 1342
# 196 1342
# 300
# 197 1342
# 198 1342
# 200 1342
# 202 1342
# 203 1342
# 204 1342
# 206 1342
# 208 1342
# Removing 330 's Successors
# 209 1342
# Removing contig-100_1649.50606 's Successors
# 212 1342
# 216 1342
# Removing 2495 's Predecessors
# 218 1342
# Removing 6935 's Successors
# 219 1342
# Removing 6847 's Successors
# Removing 2367 's Successors
# 222 1342
# 223 1342
# Removing 6545 's Successors
# 224 1342
# 225 1342
# 228 1342
# 229 1342
# Removing 249 's Successors
# 230 1342
# 231 1342
# Removing 5988 's Predecessors
# Removing 968 's Predecessors
# Removing contig-100_4724.34041 's Successors
# 232 1342
# Removing 1740 's Successors
# 233 1342
# Removing 3606 's Successors
# 237 1342
# Removing 1761 's Successors
# 238 1342
# 240 1342
# Removing 6929 's Successors
# Removing contig-100_6091.48067 's Successors
# Removing 961 's Successors
# 241 1342
# 242 1342
# Removing 5190 's Predecessors
# 243 1342
# 245 1342
# 246 1342
# 248 1342
# Removing contig-100_10694.10694 's Successors
# 249 1342
# 250 1342
# Removing 2622 's Successors
# 251 1342
# Removing contig-100_12467.12467 's Predecessors
# Removing 6428 's Successors
# Removing 1823 's Successors
# 252 1342
# Removing contig-100_1165.1165 's Predecessors
# 253 1342
# Removing contig-100_4803.46779 's Successors
# 254 1342
# 257 1342
# Removing 2259 's Successors
# Removing 1844 's Successors
# 260 1342
# 263 1342
# 265 1342
# 267 1342
# Removing 5863 's Successors
# 268 1342
# 269 1342
# 270 1342
# 271 1342
# Removing contig-100_9929.9929 's Predecessors
# Removing 2950 's Successors
# Removing 4915 's Predecessors
# 272 1342
# 275 1342
# 277 1342
# 278 1342
# Removing 1934 's Successors
# 280 1342
# Removing 2438 's Successors
# 281 1342
# Removing 435 's Successors
# 283 1342
# Removing 6506 's Successors
# 284 1342
# 285 1342
# Removing 6904 's Successors
# 288 1342
# 292 1342
# 293 1342
# 298 1342
# Removing contig-100_3153.32470 's Successors
# 300 1342
# 302 1342
# 303 1342
# Removing contig-100_8223.37540 's Successors
# 304 1342
# 306 1342
# 309 1342
# 311 1342
# 312 1342
# 300
# Removing contig-100_1767.55100 's Predecessors
# 314 1342
# Removing 6346 's Predecessors
# Removing 2099 's Successors
# 317 1342
# 319 1342
# Removing 7040 's Successors
# 322 1342
# 323 1342
# 324 1342
# Removing 5592 's Successors
# 326 1342
# 327 1342
# 328 1342
# Removing 2481 's Successors
# Removing 6974 's Successors
# 330 1342
# 331 1342
# Removing 5805 's Predecessors
# Removing contig-100_2265.51222 's Successors
# 333 1342
# 335 1342
# Removing contig-100_1968.31285 's Predecessors
# 339 1342
# Removing 6599 's Predecessors
# 340 1342
# 343 1342
# 344 1342
# 345 1342
# Removing 3402 's Predecessors
# Removing 6748 's Predecessors
# Removing contig-100_1176.54509 's Successors
# 357 1342
# 358 1342
# Removing contig-100_3509.52466 's Predecessors
# Removing 5885 's Successors
# 359 1342
# Removing 5537 's Successors
# 360 1342
# Removing contig-100_1998.50955 's Successors
# 361 1342
# Removing 5652 's Predecessors
# Removing 2319 's Predecessors
# Removing 481 's Successors
# Removing 3444 's Predecessors
# Removing 3690 's Successors
# 364 1342
# Removing 6142 's Predecessors
# 366 1342
# 367 1342
# 369 1342
# Removing contig-100_9987.39304 's Successors
# Removing contig-100_776.776 's Successors
# Removing 6044 's Successors
# 370 1342
# Removing 957 's Successors
# Removing contig-100_3650.3650 's Successors
# 371 1342
# Removing 3747 's Successors
# 374 1342
# Removing 960 's Successors
# 379 1342
# Removing 7139 's Predecessors
# 381 1342
# 383 1342
# 385 1342
# Removing contig-100_4313.46289 's Predecessors
# Removing 2445 's Predecessors
# 386 1342
# 387 1342
# Removing 600 's Successors
# 388 1342
# 392 1342
# 393 1342
# 396 1342
# Removing 5473 's Successors
# 397 1342
# 300
# 398 1342
# 400 1342
# 401 1342
# Removing contig-100_1959.50916 's Successors
# 404 1342
# Removing 6363 's Successors
# Removing 3291 's Predecessors
# 405 1342
# 406 1342
# 408 1342
# Removing 5403 's Predecessors
# 411 1342
# 413 1342
# 416 1342
# Removing 5961 's Successors
# 419 1342
# 421 1342
# Removing 5812 's Predecessors
# Removing 2730 's Successors
# Removing 6762 's Predecessors
# 427 1342
# 300
# 429 1342
# Removing 263 's Successors
# 430 1342
# 432 1342
# 434 1342
# 437 1342
# 438 1342
# 440 1342
# 441 1342
# 442 1342
# 300
# 444 1342
# 445 1342
# Removing contig-100_12334.12334 's Predecessors
# 446 1342
# 447 1342
# 448 1342
# 450 1342
# Removing contig-100_1826.55159 's Successors
# Removing contig-100_10956.10956 's Predecessors
# 451 1342
# 452 1342
# 453 1342
# Removing 7053 's Predecessors
# 454 1342
# 300
# 455 1342
# 457 1342
# 460 1342
# Removing 6720 's Successors
# 467 1342
# Removing 6571 's Successors
# 468 1342
# Removing contig-100_8182.37499 's Successors
# 469 1342
# 471 1342
# 475 1342
# Removing 5475 's Predecessors
# Removing 5767 's Predecessors
# 477 1342
# 480 1342
# Removing 7226 's Successors
# 482 1342
# 485 1342
# Removing 4351 's Successors
# 486 1342
# 494 1342
# Removing 3052 's Predecessors
# 497 1342
# Removing 5681 's Predecessors
# Removing 700 's Predecessors
# 502 1342
# Removing 3879 's Successors
# 505 1342
# 507 1342
# 513 1342
# 515 1342
# 516 1342
# Removing 5879 's Predecessors
# 518 1342
# Removing contig-100_13908.13908 's Successors
# 520 1342
# Removing 5956 's Successors
# 521 1342
# 526 1342
# 529 1342
# Removing 3290 's Predecessors
# 531 1342
# 539 1342
# Removing contig-100_3030.45006 's Successors
# 543 1342
# Removing 6211 's Successors
# 545 1342
# Removing contig-100_1147.43123 's Predecessors
# 546 1342
# Removing 5606 's Successors
# 547 1342
# 549 1342
# 553 1342
# 300
# 555 1342
# 563 1342
# 564 1342
# 565 1342
# Removing contig-100_302.53635 's Predecessors
# 566 1342
# Removing 945 's Successors
# 572 1342
# Removing 3581 's Predecessors
# 577 1342
# Removing 3588 's Successors
# 578 1342
# Removing contig-100_3733.33050 's Successors
# 579 1342
# 584 1342
# Removing 6813 's Predecessors
# 586 1342
# Removing 6956 's Predecessors
# 587 1342
# Removing 4939 's Predecessors
# 603 1342
# 604 1342
# 610 1342
# 619 1342
# 624 1342
# Removing 5703 's Successors
# Removing contig-100_2361.44337 's Predecessors
# 625 1342
# Removing 947 's Successors
# Removing 5551 's Successors
# 631 1342
# Removing contig-100_5229.34546 's Predecessors
# 638 1342
# 643 1342
# Removing contig-100_10245.10245 's Predecessors
# Removing 405 's Successors
# 646 1342
# 648 1342
# 649 1342
# 651 1342
# 653 1342
# Removing 517 's Successors
# 656 1342
# Removing 6394 's Predecessors
# 663 1342
# 671 1342
# Removing 7100 's Predecessors
# Removing 4718 's Successors
# 674 1342
# 678 1342
# 679 1342
# 683 1342
# 686 1342
# Removing 4453 's Successors
# 688 1342
# 689 1342
# Removing 4462 's Successors
# 690 1342
# 692 1342
# Removing 4570 's Successors
# 694 1342
# Removing contig-100_4787.46763 's Successors
# 699 1342
# Removing 5924 's Successors
# 702 1342
# 711 1342
# Removing 618 's Successors
# 718 1342
# 720 1342
# 730 1342
# Removing contig-100_969.54302 's Predecessors
# Removing 4994 's Successors
# 734 1342
# 300
# 735 1342
# 300
# Removing contig-100_3234.52191 's Successors
# 739 1342
# 745 1342
# 747 1342
# Removing 6285 's Successors
# 749 1342
# 753 1342
# 755 1342
# Removing 531 's Successors
# 758 1342
# 759 1342
# 771 1342
# 778 1342
# 781 1342
# 783 1342
# 790 1342
# 804 1342
# Removing 5682 's Successors
# 805 1342
# 811 1342
# Removing 6660 's Successors
# 818 1342
# 820 1342
# 300
# 823 1342
# Removing contig-100_1637.30954 's Successors
# 828 1342
# 832 1342
# Removing 7234 's Successors
# 837 1342
# 839 1342
# 840 1342
# 300
# Removing contig-100_10782.40099 's Successors
# 843 1342
# 848 1342
# 300
# 849 1342
# 300
# Removing contig-100_5259.47235 's Successors
# 850 1342
# 871 1342
# 872 1342
# Removing contig-100_1095.54428 's Predecessors
# 889 1342
# Removing 6283 's Successors
# 890 1342
# Removing contig-100_935.54268 's Successors
# 892 1342
# Removing 6550 's Predecessors
# 897 1342
# 898 1342
# 300
# 901 1342
# Removing 6492 's Predecessors
# 903 1342
# 905 1342
# 300
# 910 1342
# 925 1342
# 933 1342
# Removing 6617 's Successors
# 943 1342
# 948 1342
# 974 1342
# 979 1342
# 981 1342
# Removing 6890 's Successors
# 986 1342
# Removing 6938 's Successors
# 988 1342
# 990 1342
# Removing contig-100_1850.50807 's Successors
# 996 1342
# 1004 1342
# Removing contig-100_353.49310 's Successors
# 1010 1342
# 1016 1342
# 300
# 1020 1342
# 1039 1342
# 1043 1342
# 1044 1342
# 1052 1342
# 300
# 1059 1342
# 300
# Removing contig-100_2644.2644 's Predecessors
# 1087 1342
# 1095 1342
# Removing contig-100_2006.43982 's Successors
# 1096 1342
# 1102 1342
# Removing contig-100_1278.54611 's Predecessors
# 1106 1342
# 300
# Removing contig-100_5845.5845 's Successors
# 1107 1342
# 300
# 1116 1342
# 1131 1342
# Removing contig-100_2622.44598 's Successors
# 1146 1342
# 1153 1342
# 1174 1342
# 1191 1342
# 300
# Removing contig-100_9107.38424 's Predecessors
# 1195 1342
# 300
# 1219 1342
# 300
# Removing contig-100_3690.52647 's Successors
# 1227 1342
# 300
# 1244 1342
# 1294 1342
# SRS019397.txt
# Removing 12627 's Predecessors
# Removing 13698 's Successors
# Removing contig-100_2640.89005 's Successors
# Removing 11853 's Successors
# Removing contig-100_7581.7581 's Successors
# 0 3738
# Removing 13063 's Successors
# 1 3738
# Removing 2533 's Successors
# Removing contig-100_15589.51338 's Successors
# 2 3738
# Removing 12116 's Predecessors
# 3 3738
# 5 3738
# 7 3738
# Removing 12231 's Successors
# Removing 4397 's Successors
# 8 3738
# Removing contig-100_3613.75857 's Predecessors
# Removing contig-100_5760.71355 's Predecessors
# 13 3738
# Removing contig-100_686.55745 's Successors
# Removing contig-100_4435.4435 's Successors
# Removing 1199 's Predecessors
# Removing 5012 's Successors
# Removing 1116 's Predecessors
# 15 3738
# Removing contig-100_8075.63134 's Predecessors
# 18 3738
# 19 3738
# Removing 10043 's Successors
# 20 3738
# Removing 10046 's Predecessors
# Removing 2565 's Successors
# 22 3738
# Removing 9967 's Predecessors
# Removing 121 's Predecessors
# Removing 1650 's Predecessors
# Removing 10246 's Predecessors
# Removing 8565 's Predecessors
# Removing 9832 's Predecessors
# Removing contig-100_227.83613 's Successors
# 23 3738
# 24 3738
# 25 3738
# Removing contig-100_1994.88359 's Successors
# Removing 12796 's Predecessors
# Removing 9899 's Successors
# 26 3738
# Removing 10999 's Successors
# 27 3738
# 31 3738
# Removing contig-100_1853.82277 's Predecessors
# Removing 12495 's Successors
# 32 3738
# 33 3738
# Removing contig-100_975.84361 's Successors
# 34 3738
# 36 3738
# Removing contig-100_2668.38417 's Successors
# 37 3738
# 39 3738
# Removing contig-100_2424.88789 's Successors
# 40 3738
# Removing 4422 's Predecessors
# Removing contig-100_354.86719 's Successors
# 44 3738
# Removing contig-100_2471.88836 's Successors
# 45 3738
# 46 3738
# Removing 10090 's Successors
# 47 3738
# Removing 12586 's Successors
# 54 3738
# 55 3738
# Removing 7575 's Successors
# 57 3738
# Removing 923 's Predecessors
# 58 3738
# 60 3738
# Removing 10111 's Successors
# 62 3738
# Removing contig-100_4275.40024 's Successors
# Removing 9552 's Successors
# 64 3738
# 65 3738
# 66 3738
# 68 3738
# Removing 12854 's Predecessors
# Removing contig-100_45.80469 's Successors
# Removing 1808 's Successors
# 69 3738
# Removing 10126 's Successors
# 70 3738
# Removing 11055 's Successors
# 71 3738
# 74 3738
# Removing contig-100_8987.64046 's Predecessors
# 75 3738
# 78 3738
# Removing 10902 's Predecessors
# Removing 8280 's Successors
# 85 3738
# Removing contig-100_4009.76253 's Successors
# 87 3738
# 88 3738
# 89 3738
# Removing 7564 's Successors
# 90 3738
# Removing contig-100_1291.78164 's Predecessors
# Removing 11353 's Predecessors
# Removing 2891 's Successors
# Removing contig-100_1432.84818 's Successors
# 92 3738
# Removing 10169 's Predecessors
# Removing 5299 's Successors
# Removing 12910 's Successors
# 94 3738
# Removing contig-100_2289.88654 's Successors
# 97 3738
# 98 3738
# Removing 1018 's Successors
# 99 3738
# Removing 2541 's Predecessors
# 100 3738
# 101 3738
# Removing 6388 's Successors
# 102 3738
# Removing 73 's Successors
# 108 3738
# Removing 13564 's Successors
# Removing contig-100_384.86749 's Successors
# 109 3738
# 110 3738
# Removing contig-100_2253.88618 's Successors
# Removing 10209 's Successors
# 111 3738
# 113 3738
# 114 3738
# Removing 12422 's Successors
# 117 3738
# 118 3738
# 119 3738
# 124 3738
# 125 3738
# Removing 1957 's Predecessors
# Removing contig-100_9040.64099 's Successors
# 128 3738
# Removing 4313 's Predecessors
# Removing contig-100_2597.79470 's Successors
# 129 3738
# Removing 4630 's Predecessors
# 131 3738
# 132 3738
# 133 3738
# Removing 13528 's Successors
# 134 3738
# Removing 10697 's Predecessors
# Removing 11215 's Successors
# Removing 11874 's Predecessors
# 136 3738
# Removing 10588 's Predecessors
# Removing 2259 's Successors
# 137 3738
# Removing contig-100_1297.87662 's Predecessors
# Removing contig-100_17225.52974 's Predecessors
# Removing 11906 's Predecessors
# Removing contig-100_635.87000 's Successors
# Removing contig-100_153.86518 's Predecessors
# 138 3738
# 139 3738
# Removing contig-100_365.83751 's Successors
# 140 3738
# 141 3738
# Removing contig-100_13480.49229 's Predecessors
# Removing 11568 's Successors
# 142 3738
# Removing contig-100_1134.56193 's Successors
# Removing 10535 's Predecessors
# 144 3738
# 146 3738
# 148 3738
# Removing 3118 's Predecessors
# 149 3738
# 152 3738
# 153 3738
# 154 3738
# 155 3738
# 158 3738
# 161 3738
# 166 3738
# 169 3738
# Removing contig-100_1807.37556 's Successors
# 170 3738
# Removing contig-100_233.86598 's Predecessors
# Removing contig-100_2077.82501 's Predecessors
# 177 3738
# 178 3738
# Removing contig-100_1143.87508 's Predecessors
# Removing contig-100_17227.17227 's Successors
# Removing contig-100_2348.88713 's Successors
# 180 3738
# Removing 12482 's Predecessors
# Removing 8937 's Predecessors
# Removing 11466 's Successors
# Removing 13284 's Successors
# 181 3738
# 182 3738
# 183 3738
# 184 3738
# 185 3738
# 193 3738
# 194 3738
# 196 3738
# Removing contig-100_673.84059 's Predecessors
# Removing contig-100_2554.74798 's Successors
# 197 3738
# 198 3738
# 199 3738
# 200 3738
# 201 3738
# Removing contig-100_2407.79280 's Predecessors
# Removing 4171 's Successors
# Removing 13018 's Successors
# 203 3738
# Removing contig-100_2448.88813 's Predecessors
# 204 3738
# 206 3738
# Removing 12044 's Predecessors
# 207 3738
# Removing 8993 's Successors
# 208 3738
# Removing 2956 's Successors
# 213 3738
# 214 3738
# Removing 13435 's Successors
# 215 3738
# Removing 10441 's Successors
# Removing 1668 's Predecessors
# 216 3738
# Removing 5653 's Successors
# 217 3738
# 218 3738
# Removing contig-100_685.84071 's Predecessors
# 220 3738
# Removing contig-100_5582.71177 's Predecessors
# 224 3738
# 226 3738
# 227 3738
# 228 3738
# Removing contig-100_2160.67755 's Successors
# Removing contig-100_1350.81774 's Successors
# Removing 2383 's Predecessors
# Removing contig-100_4814.59873 's Predecessors
# Removing 9165 's Predecessors
# Removing contig-100_1821.88186 's Predecessors
# 229 3738
# 231 3738
# 232 3738
# 233 3738
# 234 3738
# Removing contig-100_419.86784 's Successors
# 237 3738
# 240 3738
# 242 3738
# Removing contig-100_3311.75555 's Successors
# 244 3738
# 245 3738
# Removing 9018 's Predecessors
# 246 3738
# 247 3738
# Removing 13673 's Successors
# 248 3738
# 249 3738
# Removing 1576 's Predecessors
# Removing contig-100_7108.7108 's Successors
# 250 3738
# Removing 10522 's Successors
# Removing 3878 's Successors
# 252 3738
# 256 3738
# Removing 1376 's Successors
# 257 3738
# Removing 599 's Successors
# 258 3738
# Removing contig-100_616.81040 's Predecessors
# 260 3738
# 261 3738
# Removing contig-100_1463.87828 's Successors
# Removing 6714 's Successors
# 264 3738
# 266 3738
# 267 3738
# Removing 1539 's Successors
# Removing contig-100_2188.88553 's Predecessors
# Removing contig-100_868.87233 's Successors
# 268 3738
# 269 3738
# 270 3738
# 275 3738
# 282 3738
# 284 3738
# 286 3738
# 287 3738
# Removing 13530 's Predecessors
# 288 3738
# 289 3738
# 293 3738
# Removing contig-100_523.83909 's Successors
# 294 3738
# 295 3738
# Removing 5136 's Successors
# 298 3738
# 299 3738
# Removing 10657 's Successors
# 307 3738
# Removing 12922 's Predecessors
# Removing 13436 's Successors
# 310 3738
# Removing 8619 's Successors
# 311 3738
# Removing 10772 's Predecessors
# 312 3738
# 300
# Removing contig-100_7224.42973 's Successors
# 313 3738
# 316 3738
# Removing contig-100_4236.69831 's Successors
# 318 3738
# Removing 12786 's Successors
# 319 3738
# Removing contig-100_1044.87409 's Predecessors
# 320 3738
# Removing contig-100_2364.82788 's Successors
# 324 3738
# Removing 11616 's Successors
# Removing 12604 's Successors
# Removing 9713 's Predecessors
# Removing 12351 's Successors
# 325 3738
# 327 3738
# Removing contig-100_9035.64094 's Successors
# 328 3738
# 300
# 330 3738
# 300
# 331 3738
# 332 3738
# 333 3738
# 335 3738
# 336 3738
# 300
# 337 3738
# 300
# 338 3738
# 339 3738
# Removing contig-100_3868.3868 's Predecessors
# Removing 11632 's Successors
# 340 3738
# 346 3738
# 348 3738
# Removing 5250 's Predecessors
# Removing 13145 's Successors
# 349 3738
# Removing 9579 's Successors
# 351 3738
# Removing 4315 's Predecessors
# 352 3738
# 355 3738
# 356 3738
# Removing 13609 's Predecessors
# 358 3738
# 359 3738
# Removing contig-100_936.87301 's Successors
# 360 3738
# 361 3738
# 365 3738
# Removing 1434 's Successors
# 369 3738
# Removing 894 's Predecessors
# Removing 1081 's Successors
# 372 3738
# Removing 9255 's Successors
# 374 3738
# 377 3738
# Removing contig-100_1982.85368 's Successors
# 379 3738
# Removing 5757 's Predecessors
# Removing 7325 's Predecessors
# Removing 3013 's Successors
# Removing contig-100_1303.84689 's Successors
# 380 3738
# Removing 2446 's Successors
# 382 3738
# Removing contig-100_611.83997 's Successors
# 384 3738
# 385 3738
# 388 3738
# 389 3738
# 390 3738
# 391 3738
# Removing 305 's Successors
# Removing 13403 's Successors
# 395 3738
# 399 3738
# 406 3738
# Removing 1209 's Predecessors
# Removing 11137 's Successors
# 407 3738
# Removing contig-100_41.72285 's Predecessors
# Removing 10904 's Successors
# 409 3738
# Removing 13226 's Successors
# Removing contig-100_4154.59213 's Predecessors
# 413 3738
# 414 3738
# Removing 12246 's Successors
# 425 3738
# Removing 12224 's Predecessors
# 432 3738
# Removing 7301 's Successors
# Removing 12741 's Successors
# 433 3738
# Removing contig-100_11528.11528 's Successors
# 434 3738
# 435 3738
# Removing 9074 's Predecessors
# 437 3738
# 441 3738
# Removing 5520 's Successors
# 444 3738
# Removing 4648 's Successors
# Removing 5589 's Predecessors
# 445 3738
# Removing 4988 's Predecessors
# Removing 3207 's Successors
# 449 3738
# 451 3738
# Removing 11013 's Predecessors
# 452 3738
# 454 3738
# 457 3738
# Removing contig-100_1714.82138 's Successors
# 458 3738
# 459 3738
# Removing contig-100_3066.79939 's Predecessors
# 460 3738
# 462 3738
# Removing 916 's Successors
# 464 3738
# 466 3738
# 467 3738
# 471 3738
# 474 3738
# 477 3738
# Removing contig-100_2038.78911 's Successors
# 478 3738
# Removing contig-100_1806.85192 's Predecessors
# Removing contig-100_364.80788 's Predecessors
# Removing 1913 's Successors
# 486 3738
# Removing 9361 's Predecessors
# 487 3738
# 488 3738
# Removing 12093 's Predecessors
# Removing 5309 's Predecessors
# Removing 3961 's Successors
# 489 3738
# 490 3738
# 493 3738
# Removing 4600 's Predecessors
# 498 3738
# 500 3738
# Removing contig-100_13258.49007 's Successors
# 501 3738
# 502 3738
# 300
# 506 3738
# 507 3738
# Removing contig-100_2287.67882 's Predecessors
# 508 3738
# Removing 11445 's Successors
# 512 3738
# 514 3738
# Removing 12615 's Successors
# 517 3738
# 519 3738
# 521 3738
# 527 3738
# 528 3738
# 532 3738
# 533 3738
# 534 3738
# Removing 13241 's Successors
# 537 3738
# 539 3738
# 300
# Removing contig-100_1682.88047 's Successors
# 540 3738
# 546 3738
# 550 3738
# Removing contig-100_2487.82911 's Successors
# 552 3738
# 555 3738
# Removing 12270 's Successors
# 556 3738
# Removing 5098 's Successors
# 558 3738
# 562 3738
# 563 3738
# Removing contig-100_1973.1973 's Predecessors
# 567 3738
# 568 3738
# 300
# 570 3738
# Removing 12314 's Successors
# 574 3738
# 578 3738
# Removing 9529 's Successors
# 585 3738
# 587 3738
# 589 3738
# 591 3738
# Removing contig-100_7220.7220 's Successors
# 593 3738
# 594 3738
# 597 3738
# 609 3738
# Removing 4088 's Predecessors
# 613 3738
# 616 3738
# 618 3738
# Removing 2882 's Predecessors
# Removing contig-100_8544.63603 's Predecessors
# Removing 2440 's Successors
# Removing 9436 's Successors
# 620 3738
# 623 3738
# Removing contig-100_3218.75462 's Predecessors
# 627 3738
# Removing 11566 's Successors
# Removing contig-100_814.84200 's Successors
# Removing 5286 's Predecessors
# 628 3738
# Removing contig-100_1028.84414 's Successors
# 629 3738
# Removing 11431 's Successors
# 631 3738
# Removing 1314 's Predecessors
# Removing 9979 's Successors
# 633 3738
# Removing 11452 's Successors
# 637 3738
# Removing 9403 's Successors
# Removing contig-100_15565.15565 's Predecessors
# Removing 1195 's Predecessors
# 642 3738
# Removing 13380 's Successors
# 643 3738
# 644 3738
# 645 3738
# 648 3738
# Removing contig-100_1170.84556 's Predecessors
# 649 3738
# 651 3738
# 652 3738
# Removing contig-100_1607.84993 's Predecessors
# 653 3738
# Removing contig-100_2169.85555 's Successors
# Removing 4300 's Successors
# 658 3738
# 660 3738
# Removing 13074 's Successors
# Removing 8362 's Predecessors
# Removing 12481 's Successors
# 661 3738
# Removing 3724 's Successors
# 662 3738
# 663 3738
# 664 3738
# Removing 8381 's Successors
# Removing 9375 's Predecessors
# 666 3738
# 668 3738
# 669 3738
# Removing contig-100_589.81013 's Successors
# 670 3738
# Removing contig-100_598.81022 's Predecessors
# Removing 11528 's Predecessors
# 671 3738
# Removing 179 's Predecessors
# 674 3738
# Removing contig-100_11167.46916 's Successors
# 678 3738
# 681 3738
# Removing 11553 's Successors
# 682 3738
# 688 3738
# 691 3738
# 692 3738
# Removing 11592 's Successors
# 693 3738
# 695 3738
# Removing 8519 's Predecessors
# Removing 17 's Successors
# 697 3738
# Removing 11606 's Predecessors
# Removing 9358 's Predecessors
# Removing contig-100_11721.11721 's Successors
# 701 3738
# 703 3738
# Removing contig-100_1890.88255 's Predecessors
# 711 3738
# Removing 11627 's Successors
# Removing 2417 's Successors
# 712 3738
# Removing contig-100_2707.89072 's Successors
# 713 3738
# 715 3738
# Removing contig-100_2365.85751 's Successors
# 717 3738
# Removing 11649 's Predecessors
# Removing 12642 's Successors
# 719 3738
# 720 3738
# 722 3738
# Removing contig-100_1483.78356 's Successors
# 723 3738
# 726 3738
# 727 3738
# []
# 729 3738
# 731 3738
# Removing 11681 's Predecessors
# Removing contig-100_2166.85552 's Successors
# 736 3738
# 738 3738
# 741 3738
# Removing 11701 's Successors
# 742 3738
# Removing contig-100_2999.75243 's Predecessors
# 743 3738
# 746 3738
# Removing contig-100_13182.48931 's Predecessors
# 748 3738
# Removing contig-100_2319.85705 's Successors
# 749 3738
# Removing contig-100_1903.85289 's Predecessors
# 750 3738
# 751 3738
# Removing 3896 's Predecessors
# 752 3738
# 754 3738
# 757 3738
# Removing contig-100_2012.82436 's Predecessors
# 758 3738
# 759 3738
# Removing contig-100_1654.56713 's Successors
# 760 3738
# 761 3738
# Removing 13683 's Predecessors
# 762 3738
# Removing 2924 's Predecessors
# 770 3738
# 771 3738
# Removing 2867 's Successors
# 773 3738
# 776 3738
# 779 3738
# Removing 9718 's Predecessors
# 784 3738
# 300
# Removing 5977 's Predecessors
# 785 3738
# 787 3738
# Removing 12846 's Successors
# 788 3738
# 789 3738
# 791 3738
# 793 3738
# 796 3738
# 798 3738
# Removing contig-100_12376.12376 's Predecessors
# Removing 9634 's Successors
# 799 3738
# 803 3738
# Removing 2357 's Predecessors
# Removing 515 's Successors
# 804 3738
# 805 3738
# 809 3738
# 810 3738
# 811 3738
# 815 3738
# Removing contig-100_870.870 's Predecessors
# Removing 11891 's Predecessors
# 816 3738
# Removing 5477 's Successors
# 817 3738
# 818 3738
# 820 3738
# 821 3738
# 824 3738
# 826 3738
# 828 3738
# Removing contig-100_2382.88747 's Predecessors
# 830 3738
# Removing contig-100_1536.73780 's Predecessors
# 834 3738
# 837 3738
# Removing 5255 's Predecessors
# Removing 11972 's Predecessors
# Removing contig-100_15097.50846 's Predecessors
# 844 3738
# 846 3738
# 848 3738
# 852 3738
# 853 3738
# 855 3738
# 856 3738
# Removing contig-100_1557.81981 's Predecessors
# Removing contig-100_1306.78179 's Successors
# 859 3738
# 860 3738
# 867 3738
# 870 3738
# 871 3738
# 872 3738
# Removing 12029 's Predecessors
# 873 3738
# 874 3738
# Removing 8664 's Successors
# 877 3738
# 881 3738
# Removing 12313 's Predecessors
# 886 3738
# Removing 799 's Successors
# 887 3738
# 889 3738
# 891 3738
# Removing 2230 's Predecessors
# Removing 3053 's Predecessors
# 893 3738
# 894 3738
# Removing 12087 's Predecessors
# Removing contig-100_9039.44788 's Successors
# Removing 12962 's Successors
# 895 3738
# Removing 12088 's Predecessors
# 896 3738
# Removing 444 's Successors
# 899 3738
# 902 3738
# Removing 2615 's Successors
# 904 3738
# 905 3738
# Removing contig-100_1600.67195 's Predecessors
# 912 3738
# 919 3738
# 920 3738
# 921 3738
# Removing 12164 's Predecessors
# 922 3738
# 924 3738
# 938 3738
# Removing 12738 's Successors
# 942 3738
# 943 3738
# Removing 13537 's Predecessors
# 944 3738
# 945 3738
# 946 3738
# 947 3738
# 948 3738
# Removing contig-100_1927.78800 's Successors
# 949 3738
# Removing 2154 's Predecessors
# Removing 12237 's Successors
# 951 3738
# 956 3738
# Removing 3860 's Successors
# 957 3738
# 958 3738
# 961 3738
# 962 3738
# Removing 12275 's Successors
# 964 3738
# 969 3738
# 973 3738
# 974 3738
# Removing 12312 's Successors
# 979 3738
# Removing contig-100_6067.6067 's Successors
# 987 3738
# 989 3738
# 300
# Removing contig-100_2480.88845 's Predecessors
# 992 3738
# Removing contig-100_8317.63376 's Predecessors
# 993 3738
# 300
# 994 3738
# Removing 12389 's Predecessors
# 996 3738
# 999 3738
# 1001 3738
# 1002 3738
# Removing 2140 's Successors
# 1003 3738
# 1004 3738
# Removing 12940 's Predecessors
# 1006 3738
# 1008 3738
# 300
# 1010 3738
# 1011 3738
# 1016 3738
# Removing contig-100_1459.81883 's Predecessors
# Removing contig-100_4632.70227 's Successors
# 1017 3738
# Removing contig-100_2412.88777 's Successors
# 1020 3738
# Removing 311 's Successors
# 1022 3738
# Removing 4375 's Predecessors
# Removing contig-100_439.83825 's Successors
# 1023 3738
# Removing 558 's Successors
# Removing contig-100_132.83518 's Successors
# 1024 3738
# 1025 3738
# 1026 3738
# 1029 3738
# 1032 3738
# 1036 3738
# 1038 3738
# 1039 3738
# 1040 3738
# 1041 3738
# Removing contig-100_2196.88561 's Successors
# 1045 3738
# 1050 3738
# Removing 12565 's Predecessors
# Removing 56 's Successors
# 1051 3738
# Removing 1458 's Successors
# 1052 3738
# Removing 190 's Successors
# Removing contig-100_1598.84984 's Successors
# 1054 3738
# Removing contig-100_539.86904 's Predecessors
# 1056 3738
# 1057 3738
# 1060 3738
# 1065 3738
# 1067 3738
# Removing contig-100_2545.82969 's Predecessors
# Removing contig-100_1929.85315 's Predecessors
# 1068 3738
# 1070 3738
# 1072 3738
# 1075 3738
# 1076 3738
# 1079 3738
# Removing 13597 's Predecessors
# 1080 3738
# 1082 3738
# 1083 3738
# Removing contig-100_1481.87846 's Predecessors
# 1086 3738
# 1089 3738
# Removing 13065 's Successors
# 1090 3738
# Removing contig-100_735.87100 's Successors
# 1092 3738
# 1093 3738
# Removing 9863 's Successors
# 1094 3738
# 1101 3738
# 1102 3738
# 1106 3738
# 1111 3738
# 1112 3738
# 1116 3738
# 1120 3738
# 1122 3738
# Removing 13532 's Successors
# 1123 3738
# Removing 12946 's Successors
# 1124 3738
# 1127 3738
# 1128 3738
# 1132 3738
# 1133 3738
# 1135 3738
# Removing 8154 's Predecessors
# Removing 12958 's Successors
# 1139 3738
# Removing contig-100_2492.88857 's Predecessors
# 1140 3738
# Removing contig-100_6631.6631 's Successors
# 1143 3738
# 1144 3738
# Removing contig-100_2380.88745 's Successors
# 1146 3738
# 1153 3738
# 300
# 1154 3738
# 1156 3738
# Removing contig-100_3367.75611 's Successors
# 1159 3738
# Removing 13322 's Successors
# Removing 9404 's Successors
# Removing 12916 's Successors
# 1161 3738
# Removing 3973 's Successors
# 1162 3738
# Removing 12920 's Successors
# 1163 3738
# 1164 3738
# 1165 3738
# 1167 3738
# 1172 3738
# 1173 3738
# 1174 3738
# 1176 3738
# 1180 3738
# 1181 3738
# 1187 3738
# 1188 3738
# Removing contig-100_490.86855 's Successors
# 1189 3738
# 1191 3738
# Removing 13487 's Predecessors
# 1193 3738
# 1195 3738
# 1199 3738
# Removing 9122 's Successors
# 1201 3738
# 1202 3738
# Removing contig-100_5809.60868 's Successors
# 1203 3738
# Removing 8015 's Predecessors
# 1205 3738
# 1208 3738
# 1210 3738
# 1212 3738
# Removing contig-100_619.84005 's Successors
# 1214 3738
# 1215 3738
# 1223 3738
# 1224 3738
# Removing 13580 's Predecessors
# 1226 3738
# Removing contig-100_950.87315 's Predecessors
# 1233 3738
# Removing 13206 's Successors
# 1234 3738
# Removing contig-100_2787.79660 's Predecessors
# 1244 3738
# Removing 4815 's Successors
# 1250 3738
# 1253 3738
# Removing 13292 's Successors
# 1255 3738
# Removing contig-100_4288.69883 's Successors
# 1260 3738
# Removing 13314 's Predecessors
# 1262 3738
# Removing contig-100_2674.79547 's Successors
# 1263 3738
# Removing contig-100_2902.79775 's Predecessors
# 1265 3738
# 1267 3738
# Removing 8199 's Successors
# 1268 3738
# 1269 3738
# 1272 3738
# Removing 1335 's Successors
# 1273 3738
# Removing contig-100_2430.82854 's Predecessors
# 1278 3738
# Removing contig-100_2285.82709 's Predecessors
# 1280 3738
# 1287 3738
# 300
# 1290 3738
# Removing 13424 's Successors
# 1291 3738
# Removing 9856 's Predecessors
# 1292 3738
# Removing 13450 's Successors
# 1299 3738
# 1301 3738
# Removing contig-100_1600.84986 's Successors
# 1306 3738
# 1308 3738
# 1309 3738
# Removing 13494 's Successors
# 1311 3738
# Removing contig-100_1636.88001 's Successors
# 1313 3738
# 1316 3738
# 1318 3738
# 1325 3738
# 1326 3738
# Removing contig-100_1433.87798 's Successors
# 1328 3738
# 1329 3738
# 1333 3738
# 1335 3738
# Removing contig-100_2774.89139 's Successors
# 1336 3738
# 1337 3738
# 1338 3738
# 1341 3738
# Removing contig-100_2261.88626 's Predecessors
# Removing 159 's Successors
# 1342 3738
# 1348 3738
# 1349 3738
# Removing 13692 's Predecessors
# 1350 3738
# 1351 3738
# 1352 3738
# 1359 3738
# Removing contig-100_9428.45177 's Predecessors
# 1360 3738
# 1366 3738
# Removing 3066 's Predecessors
# 1367 3738
# Removing 9689 's Predecessors
# Removing 6173 's Predecessors
# 1370 3738
# Removing 2716 's Predecessors
# Removing 143 's Successors
# Removing 738 's Successors
# 1373 3738
# 1377 3738
# 1379 3738
# Removing 8563 's Successors
# 1381 3738
# 1382 3738
# 1383 3738
# 1385 3738
# Removing 2425 's Predecessors
# 1387 3738
# 1390 3738
# 1392 3738
# Removing 1708 's Predecessors
# 1393 3738
# 1394 3738
# Removing 9429 's Successors
# 1395 3738
# 1397 3738
# Removing contig-100_1465.1465 's Successors
# 1400 3738
# Removing 6880 's Successors
# 1403 3738
# 1406 3738
# 1407 3738
# Removing 1671 's Successors
# 1412 3738
# Removing 171 's Successors
# 1418 3738
# Removing 9636 's Predecessors
# 1419 3738
# 1426 3738
# 1427 3738
# 1432 3738
# 1440 3738
# 300
# Removing 1866 's Successors
# 1441 3738
# 1442 3738
# 1444 3738
# Removing contig-100_1802.82226 's Successors
# 1447 3738
# 1449 3738
# 1452 3738
# 1457 3738
# Removing contig-100_588.588 's Successors
# 1463 3738
# 1468 3738
# 1469 3738
# 1471 3738
# 1472 3738
# 1473 3738
# 1481 3738
# 1483 3738
# Removing 4210 's Predecessors
# Removing 3486 's Predecessors
# 1488 3738
# Removing 2234 's Successors
# 1492 3738
# 1495 3738
# 1496 3738
# 1504 3738
# 1505 3738
# 1507 3738
# Removing 2304 's Successors
# 1508 3738
# Removing 235 's Predecessors
# 1511 3738
# 1513 3738
# Removing contig-100_456.83842 's Predecessors
# 1525 3738
# Removing contig-100_15765.15765 's Successors
# 1528 3738
# 1529 3738
# 1539 3738
# Removing 7227 's Predecessors
# 1541 3738
# Removing 8615 's Predecessors
# 1542 3738
# Removing contig-100_2474.88839 's Predecessors
# 1553 3738
# 1556 3738
# Removing 4350 's Successors
# Removing contig-100_13389.13389 's Successors
# 1559 3738
# 1561 3738
# 1563 3738
# 1568 3738
# 1577 3738
# Removing contig-100_1628.78501 's Successors
# 1579 3738
# 1581 3738
# 1582 3738
# 1585 3738
# 1590 3738
# 1601 3738
# 1602 3738
# 1606 3738
# 1607 3738
# 1625 3738
# 1626 3738
# 1629 3738
# 1631 3738
# Removing 6129 's Successors
# 1648 3738
# 1653 3738
# Removing 3331 's Predecessors
# 1661 3738
# 1666 3738
# 1668 3738
# Removing contig-100_13817.49566 's Successors
# 1669 3738
# 1670 3738
# Removing 9821 's Successors
# 1687 3738
# 1693 3738
# 1712 3738
# 1723 3738
# 1731 3738
# Removing contig-100_986.87351 's Successors
# 1732 3738
# 1734 3738
# Removing contig-100_1324.87689 's Predecessors
# 1735 3738
# Removing 8545 's Successors
# 1737 3738
# Removing 3855 's Successors
# 1745 3738
# Removing 9146 's Successors
# 1752 3738
# 1758 3738
# 1762 3738
# Removing contig-100_2538.88903 's Successors
# 1766 3738
# Removing 8869 's Successors
# 1780 3738
# Removing 4274 's Predecessors
# Removing 4185 's Successors
# 1783 3738
# Removing contig-100_3683.69278 's Successors
# 1785 3738
# 1786 3738
# 1818 3738
# 300
# 1823 3738
# 1827 3738
# Removing 9785 's Successors
# 1831 3738
# 1840 3738
# Removing 4720 's Successors
# Removing contig-100_2843.38592 's Successors
# Removing 8735 's Successors
# 1853 3738
# 1857 3738
# 1860 3738
# 300
# Removing contig-100_10660.46409 's Predecessors
# 1884 3738
# 1885 3738
# Removing 9323 's Successors
# 1886 3738
# 1900 3738
# 1912 3738
# 1916 3738
# 1917 3738
# Removing 5161 's Successors
# 1918 3738
# 1928 3738
# 300
# 1937 3738
# Removing 9884 's Predecessors
# 1939 3738
# 1940 3738
# Removing contig-100_3525.75769 's Successors
# 1944 3738
# Removing 5400 's Successors
# 1954 3738
# Removing contig-100_1594.73838 's Successors
# 1967 3738
# 1974 3738
# Removing contig-100_3122.68717 's Successors
# 1992 3738
# 1999 3738
# 2009 3738
# 2010 3738
# Removing 5814 's Successors
# 2013 3738
# Removing contig-100_15337.15337 's Successors
# 2036 3738
# 2038 3738
# 2042 3738
# 2047 3738
# 2049 3738
# 2053 3738
# 2063 3738
# Removing contig-100_1909.82333 's Successors
# 2064 3738
# 2077 3738
# 2080 3738
# 2085 3738
# 2092 3738
# 2104 3738
# 2153 3738
# 2157 3738
# 2160 3738
# 2167 3738
# 2178 3738
# Removing 9239 's Predecessors
# 2184 3738
# 2195 3738
# Removing 9226 's Successors
# Removing contig-100_250.72494 's Successors
# 2200 3738
# 2213 3738
# 2237 3738
# 2240 3738
# Removing contig-100_3046.75290 's Successors
# 2244 3738
# 2264 3738
# 2284 3738
# 2295 3738
# 2303 3738
# 2314 3738
# 2315 3738
# 2331 3738
# 2350 3738
# Removing 8989 's Successors
# 2353 3738
# 2362 3738
# 2364 3738
# Removing contig-100_1147.81571 's Successors
# 2381 3738
# 2382 3738
# 2383 3738
# 2384 3738
# 300
# Removing contig-100_4068.39817 's Successors
# 2400 3738
# 2403 3738
# Removing 9787 's Successors
# 2417 3738
# 2424 3738
# Removing 9070 's Predecessors
# 2436 3738
# 2469 3738
# 2500 3738
# 300
# 2503 3738
# 2507 3738
# 2522 3738
# 2525 3738
# 2542 3738
# 2553 3738
# 2571 3738
# 2591 3738
# 2634 3738
# 300
# Removing contig-100_11062.11062 's Successors
# 2642 3738
# 300
# Removing contig-100_17616.53365 's Successors
# 2648 3738
# 2650 3738
# 2653 3738
# 2667 3738
# 2673 3738
# 300
# 2674 3738
# 2681 3738
# 300
# 2696 3738
# 2728 3738
# 2744 3738
# 2754 3738
# 300
# 2764 3738
# 2773 3738
# 2796 3738
# Removing contig-100_1405.84791 's Successors
# 2814 3738
# 2846 3738
# 2864 3738
# Removing contig-100_2167.85553 's Successors
# 2884 3738
# 2912 3738
# 300
# 2981 3738
# Removing contig-100_2979.89344 's Predecessors
# 2982 3738
# 3022 3738
# 3049 3738
# 300
# 3056 3738
# 300
# 3068 3738
# 300
# Removing contig-100_2151.85537 's Successors
# 3079 3738
# 3138 3738
# 3139 3738
# 300
# 3153 3738
# 300
# 3204 3738
# 300
# 3221 3738
# 300
# 3226 3738
# 3244 3738
# 3251 3738
# 300
# Removing contig-100_3073.75317 's Successors
# 3303 3738
# 3312 3738
# 300
# Removing contig-100_3639.3639 's Successors
# 3363 3738
# 300
# Removing contig-100_3705.39454 's Predecessors
# 3368 3738
# 3370 3738
# 3385 3738
# SRS019787.txt
# Removing 12478 's Successors
# 0 3012
# 1 3012
# Removing 13748 's Successors
# 2 3012
# Removing 11398 's Predecessors
# 6 3012
# Removing contig-100_621.621 's Predecessors
# Removing 12763 's Predecessors
# Removing 257 's Successors
# 7 3012
# 8 3012
# 13 3012
# Removing 1002 's Predecessors
# 14 3012
# 15 3012
# Removing 10024 's Predecessors
# 16 3012
# 17 3012
# ...
# 429 3012
# 432 3012
# Removing 3472 's Successors
# 434 3012
# 435 3012
# 438 3012
# 440 3012
# 443 3012
# 447 3012
# 448 3012
# Removing 11141 's Successors
# 449 3012
# 450 3012
# Removing contig-100_2065.67400 's Successors
# 454 3012
# Removing contig-100_1168.73511 's Successors
# 458 3012
# Removing contig-100_2098.79039 's Predecessors
# 460 3012
# 461 3012
# Removing 11173 's Successors
# 462 3012
# Removing contig-100_1943.74286 's Successors
# 464 3012
# 465 3012
# Removing contig-100_1482.81711 's Successors
# 467 3012
# 468 3012
# 474 3012
# Removing contig-100_184.184 's Successors
# 475 3012
# 477 3012
# 478 3012
# Removing contig-100_6867.60620 's Successors
# 479 3012
# 480 3012
# 481 3012
# 482 3012
# 483 3012
# Removing 1125 's Predecessors
# 485 3012
# Removing 5689 's Predecessors
# Removing 6714 's Predecessors
# 486 3012
# 487 3012
# Removing 11265 's Predecessors
# 492 3012
# 494 3012
# 495 3012
# 496 3012
# 499 3012
# Removing 11285 's Successors
# 501 3012
# 503 3012
# 504 3012
# 510 3012
# Removing 1878 's Successors
# Removing 12932 's Predecessors
# 511 3012
# 512 3012
# 513 3012
# 300
# Removing 11332 's Successors
# 517 3012
# 518 3012
# Removing contig-100_2058.82287 's Predecessors
# 520 3012
# Removing 11353 's Successors
# 522 3012
# 524 3012
# 525 3012
# 528 3012
# 531 3012
# Removing contig-100_6369.71704 's Predecessors
# Removing contig-100_2850.75193 's Successors
# 533 3012
# Removing 2562 's Successors
# 534 3012
# 535 3012
# Removing 12934 's Predecessors
# Removing 12839 's Successors
# Removing 1435 's Successors
# 538 3012
# 540 3012
# 544 3012
# 545 3012
# 548 3012
# 300
# 550 3012
# 553 3012
# 555 3012
# Removing contig-100_1594.78535 's Successors
# 556 3012
# 557 3012
# 558 3012
# Removing 1787 's Predecessors
# 560 3012
# Removing 8214 's Successors
# 561 3012
# 563 3012
# Removing contig-100_1823.55576 's Successors
# 564 3012
# 566 3012
# 567 3012
# 568 3012
# 569 3012
# Removing 1176 's Successors
# 570 3012
# Removing 11504 's Predecessors
# 571 3012
# Removing contig-100_1785.78726 's Predecessors
# 572 3012
# 575 3012
# Removing 4387 's Predecessors
# Removing 2520 's Predecessors
# 577 3012
# 300
# Removing 13949 's Successors
# 578 3012
# Removing 239 's Predecessors
# 579 3012
# 300
# 580 3012
# 581 3012
# 582 3012
# 587 3012
# Removing 12738 's Predecessors
# 588 3012
# Removing 4015 's Successors
# 589 3012
# 590 3012
# Removing 4819 's Successors
# 591 3012
# 592 3012
# 594 3012
# 597 3012
# Removing 11575 's Successors
# 598 3012
# 599 3012
# 600 3012
# 601 3012
# 606 3012
# 607 3012
# Removing 8925 's Predecessors
# 608 3012
# 610 3012
# 612 3012
# Removing 11627 's Predecessors
# 615 3012
# Removing 8383 's Successors
# 616 3012
# 300
# 618 3012
# 621 3012
# 623 3012
# 627 3012
# 300
# Removing contig-100_5835.71170 's Predecessors
# 628 3012
# Removing 11661 's Successors
# 629 3012
# Removing 3993 's Predecessors
# 631 3012
# 632 3012
# 635 3012
# 300
# Removing 5162 's Successors
# 636 3012
# Removing 12123 's Successors
# Removing 8235 's Successors
# 639 3012
# 644 3012
# 300
# 647 3012
# Removing contig-100_6394.38762 's Successors
# 652 3012
# 653 3012
# Removing 11727 's Predecessors
# 655 3012
# 657 3012
# 664 3012
# Removing 13431 's Predecessors
# 666 3012
# Removing 12972 's Successors
# 668 3012
# 677 3012
# 678 3012
# 679 3012
# 680 3012
# 681 3012
# 682 3012
# 687 3012
# Removing 236 's Successors
# Removing 12510 's Successors
# Removing 2335 's Predecessors
# 690 3012
# Removing 9521 's Successors
# 691 3012
# 692 3012
# Removing contig-100_1075.73418 's Successors
# 693 3012
# Removing 1440 's Successors
# 694 3012
# 697 3012
# 698 3012
# 703 3012
# Removing 7067 's Successors
# Removing 7126 's Successors
# 704 3012
# 706 3012
# Removing 13713 's Successors
# Removing 567 's Successors
# 708 3012
# 711 3012
# 714 3012
# Removing 12459 's Predecessors
# 715 3012
# 716 3012
# Removing 14028 's Predecessors
# 717 3012
# Removing 11953 's Predecessors
# 718 3012
# 719 3012
# 720 3012
# Removing 11967 's Successors
# 721 3012
# Removing contig-100_9859.63612 's Successors
# 722 3012
# 723 3012
# 724 3012
# Removing 8428 's Predecessors
# Removing 3773 's Successors
# 725 3012
# 727 3012
# Removing contig-100_1688.81917 's Successors
# 729 3012
# Removing 13331 's Predecessors
# Removing contig-100_407.80636 's Successors
# Removing 2785 's Successors
# 730 3012
# 733 3012
# 734 3012
# 735 3012
# 736 3012
# 737 3012
# 740 3012
# Removing 9579 's Successors
# 741 3012
# Removing 12038 's Predecessors
# 742 3012
# Removing contig-100_15386.47754 's Predecessors
# 745 3012
# 749 3012
# 753 3012
# 755 3012
# Removing 1651 's Predecessors
# Removing 12141 's Successors
# 756 3012
# Removing 9903 's Successors
# 757 3012
# 760 3012
# Removing contig-100_2064.82293 's Predecessors
# 761 3012
# Removing 12095 's Successors
# 763 3012
# 764 3012
# Removing 9147 's Successors
# 765 3012
# 766 3012
# 767 3012
# 768 3012
# 769 3012
# Removing 5784 's Predecessors
# Removing contig-100_954.83773 's Successors
# 771 3012
# 774 3012
# 780 3012
# 783 3012
# 784 3012
# Removing 12171 's Predecessors
# 788 3012
# Removing 12178 's Successors
# 790 3012
# Removing 12186 's Predecessors
# 793 3012
# 794 3012
# 797 3012
# 799 3012
# 800 3012
# Removing contig-100_3659.68994 's Successors
# 801 3012
# 803 3012
# 806 3012
# 300
# 809 3012
# Removing 12248 's Successors
# 812 3012
# Removing 6805 's Predecessors
# 813 3012
# 814 3012
# 816 3012
# 817 3012
# Removing contig-100_531.80760 's Successors
# 820 3012
# 825 3012
# 828 3012
# 829 3012
# 833 3012
# 834 3012
# 836 3012
# Removing 8329 's Predecessors
# Removing 578 's Predecessors
# Removing contig-100_1276.81505 's Predecessors
# Removing 12324 's Predecessors
# 837 3012
# 839 3012
# 842 3012
# 844 3012
# Removing 13999 's Successors
# 845 3012
# 847 3012
# 848 3012
# 849 3012
# Removing 12366 's Successors
# 850 3012
# 853 3012
# Removing 12386 's Successors
# 855 3012
# 856 3012
# Removing contig-100_5800.59553 's Successors
# 860 3012
# 866 3012
# Removing contig-100_1852.67187 's Successors
# 868 3012
# 869 3012
# Removing 9654 's Successors
# 870 3012
# 872 3012
# Removing contig-100_0.80229 's Predecessors
# Removing 9949 's Predecessors
# Removing 505 's Successors
# 874 3012
# 876 3012
# 881 3012
# 882 3012
# 883 3012
# 885 3012
# 887 3012
# Removing contig-100_1684.1684 's Predecessors
# 888 3012
# 890 3012
# 894 3012
# 898 3012
# 899 3012
# Removing 12542 's Successors
# 900 3012
# Removing 13823 's Successors
# 901 3012
# Removing contig-100_1589.78530 's Successors
# 902 3012
# 903 3012
# 906 3012
# 908 3012
# 911 3012
# 913 3012
# 915 3012
# Removing 2063 's Successors
# 919 3012
# 920 3012
# 921 3012
# Removing 1978 's Predecessors
# 924 3012
# 925 3012
# 927 3012
# 928 3012
# 931 3012
# Removing contig-100_1322.81551 's Predecessors
# 932 3012
# 935 3012
# 936 3012
# 942 3012
# 943 3012
# 948 3012
# 949 3012
# 950 3012
# 951 3012
# 953 3012
# 954 3012
# 956 3012
# 958 3012
# 960 3012
# Removing 2173 's Successors
# 962 3012
# 963 3012
# Removing 12792 's Successors
# Removing 3608 's Successors
# Removing 13078 's Successors
# 964 3012
# 965 3012
# Removing contig-100_2462.34830 's Predecessors
# 966 3012
# 968 3012
# 969 3012
# 971 3012
# Removing 12812 's Successors
# 973 3012
# 975 3012
# 977 3012
# 981 3012
# 988 3012
# Removing contig-100_2638.74981 's Successors
# Removing 12868 's Successors
# Removing 4952 's Predecessors
# Removing 3123 's Successors
# 991 3012
# 993 3012
# 997 3012
# 998 3012
# Removing contig-100_1644.81873 's Successors
# 999 3012
# Removing contig-100_4050.76393 's Predecessors
# Removing 9852 's Successors
# Removing 12905 's Predecessors
# Removing 6207 's Predecessors
# 1005 3012
# 1011 3012
# Removing 1637 's Predecessors
# 1012 3012
# 1015 3012
# Removing 919 's Predecessors
# 1018 3012
# Removing 13106 's Predecessors
# Removing contig-100_13778.46146 's Successors
# 1025 3012
# 1026 3012
# 1028 3012
# 1029 3012
# Removing 9153 's Successors
# 1030 3012
# 1032 3012
# 1033 3012
# Removing 6738 's Successors
# Removing 8912 's Predecessors
# 1039 3012
# Removing contig-100_1934.1934 's Successors
# 1042 3012
# 300
# 1044 3012
# 300
# Removing 13074 's Predecessors
# 1045 3012
# 1047 3012
# 1051 3012
# Removing contig-100_9770.63523 's Successors
# 1054 3012
# 1056 3012
# 300
# Removing contig-100_5380.59133 's Successors
# 1059 3012
# 1065 3012
# 1066 3012
# 1067 3012
# Removing 8831 's Predecessors
# 1071 3012
# Removing contig-100_4086.69421 's Successors
# 1072 3012
# 1073 3012
# 1075 3012
# Removing 13186 's Predecessors
# Removing 9834 's Successors
# 1078 3012
# 1080 3012
# Removing contig-100_4142.57895 's Successors
# 1088 3012
# 1089 3012
# Removing 384 's Predecessors
# Removing contig-100_1628.81857 's Successors
# Removing 9161 's Successors
# Removing 8855 's Successors
# 1090 3012
# 1091 3012
# Removing 9494 's Successors
# 1092 3012
# Removing 5206 's Successors
# Removing contig-100_10497.64250 's Successors
# 1096 3012
# Removing 2301 's Predecessors
# 1102 3012
# Removing contig-100_3906.69241 's Successors
# 1103 3012
# 1104 3012
# 1105 3012
# 1107 3012
# 1109 3012
# 1110 3012
# 1111 3012
# Removing contig-100_2382.79323 's Successors
# 1112 3012
# Removing contig-100_2392.79333 's Predecessors
# 1113 3012
# Removing 13832 's Successors
# 1114 3012
# 1115 3012
# 1122 3012
# 1126 3012
# 1127 3012
# 1131 3012
# Removing contig-100_3496.75839 's Predecessors
# 1138 3012
# 1139 3012
# 1141 3012
# 1142 3012
# Removing 13422 's Successors
# 1147 3012
# Removing 8751 's Predecessors
# 1148 3012
# 1149 3012
# Removing 8713 's Predecessors
# Removing contig-100_1764.81993 's Successors
# 1151 3012
# Removing 7147 's Predecessors
# Removing 4463 's Successors
# 1152 3012
# 1154 3012
# 1157 3012
# 1159 3012
# 1160 3012
# Removing contig-100_4622.36990 's Successors
# 1161 3012
# 1162 3012
# 1164 3012
# Removing 8551 's Successors
# 1165 3012
# Removing 13491 's Successors
# 1169 3012
# Removing contig-100_9063.62816 's Predecessors
# 1170 3012
# 300
# 1181 3012
# Removing 13533 's Predecessors
# 1182 3012
# 1186 3012
# 1187 3012
# 1188 3012
# 1189 3012
# 1191 3012
# 1194 3012
# 1200 3012
# 1203 3012
# 1204 3012
# 1205 3012
# 300
# 1208 3012
# 1209 3012
# 1210 3012
# 1211 3012
# 1212 3012
# 300
# 1213 3012
# 300
# 1214 3012
# 1215 3012
# Removing contig-100_386.83205 's Predecessors
# Removing contig-100_2759.79700 's Predecessors
# 1216 3012
# 1220 3012
# Removing 14037 's Successors
# 1221 3012
# 1223 3012
# 1227 3012
# 1230 3012
# 1233 3012
# 1234 3012
# 1239 3012
# Removing 13742 's Predecessors
# 1243 3012
# Removing contig-100_739.80968 's Predecessors
# Removing 8486 's Successors
# 1245 3012
# 1247 3012
# 1250 3012
# 1252 3012
# 1255 3012
# Removing contig-100_1433.33801 's Predecessors
# 1256 3012
# Removing contig-100_2002.78943 's Successors
# 1258 3012
# 1260 3012
# 1261 3012
# 1266 3012
# Removing contig-100_4918.70253 's Predecessors
# Removing 13842 's Successors
# 1267 3012
# 1270 3012
# 1271 3012
# 300
# Removing 13858 's Successors
# 1272 3012
# 1273 3012
# Removing 1388 's Predecessors
# 1278 3012
# Removing contig-100_2.80231 's Successors
# 1279 3012
# 1284 3012
# 1287 3012
# 1291 3012
# 300
# 1293 3012
# 1294 3012
# Removing contig-100_1411.81640 's Predecessors
# 1304 3012
# Removing contig-100_2929.68264 's Predecessors
# 1312 3012
# Removing 14009 's Successors
# 1314 3012
# Removing contig-100_2806.75149 's Successors
# 1315 3012
# 1316 3012
# 1319 3012
# 1322 3012
# 1323 3012
# 1326 3012
# 1328 3012
# Removing 14057 's Predecessors
# 1331 3012
# 1334 3012
# 300
# 1336 3012
# 1340 3012
# 1344 3012
# 1348 3012
# Removing 8281 's Successors
# 1350 3012
# Removing contig-100_3113.35481 's Predecessors
# 1351 3012
# Removing 867 's Predecessors
# 1353 3012
# 1354 3012
# Removing 1479 's Successors
# 1355 3012
# Removing 148 's Successors
# 1356 3012
# 1357 3012
# 300
# Removing 925 's Successors
# 1358 3012
# Removing contig-100_14826.47194 's Successors
# 1360 3012
# Removing 1503 's Successors
# 1362 3012
# Removing 9030 's Successors
# 1363 3012
# Removing 1519 's Successors
# 1364 3012
# 1365 3012
# Removing 1591 's Successors
# 1367 3012
# 1368 3012
# 300
# Removing contig-100_10793.10793 's Successors
# 1372 3012
# Removing contig-100_1941.82170 's Successors
# Removing 2788 's Successors
# 1374 3012
# 1376 3012
# Removing 1652 's Successors
# Removing 4654 's Successors
# 1377 3012
# 1379 3012
# 1381 3012
# Removing contig-100_11477.43845 's Successors
# 1385 3012
# Removing contig-100_6067.71402 's Successors
# 1386 3012
# Removing 1775 's Predecessors
# 1391 3012
# 1395 3012
# 1399 3012
# 1402 3012
# 1403 3012
# 1413 3012
# 1414 3012
# 1416 3012
# Removing contig-100_2666.79607 's Predecessors
# Removing contig-100_5452.70787 's Successors
# 1418 3012
# 1419 3012
# 300
# Removing contig-100_4213.76556 's Successors
# 1420 3012
# 1423 3012
# 1424 3012
# Removing 2122 's Successors
# 1425 3012
# 300
# 1430 3012
# 1431 3012
# 1432 3012
# 1433 3012
# 1435 3012
# Removing 2453 's Successors
# 1437 3012
# 1441 3012
# 1445 3012
# 1451 3012
# 1453 3012
# Removing 2438 's Successors
# 1460 3012
# 1463 3012
# 1467 3012
# 1468 3012
# Removing 6680 's Predecessors
# 1473 3012
# 1476 3012
# 1479 3012
# Removing 8570 's Predecessors
# 1484 3012
# 1489 3012
# 1490 3012
# Removing 7281 's Successors
# 1494 3012
# Removing contig-100_1280.78221 's Successors
# 1502 3012
# 1505 3012
# 1506 3012
# 1516 3012
# 1518 3012
# 1521 3012
# 1525 3012
# 1537 3012
# 1540 3012
# 1544 3012
# Removing 3327 's Successors
# 1546 3012
# 1554 3012
# 1562 3012
# 1563 3012
# 300
# 1565 3012
# Removing 3464 's Successors
# 1568 3012
# Removing 6567 's Successors
# 1569 3012
# 1579 3012
# 300
# Removing contig-100_6335.60088 's Predecessors
# 1580 3012
# 1582 3012
# 1583 3012
# 300
# 1585 3012
# 1587 3012
# 1592 3012
# 300
# Removing contig-100_7717.7717 's Predecessors
# 1601 3012
# Removing 984 's Predecessors
# 1611 3012
# 1612 3012
# 1614 3012
# Removing 600 's Predecessors
# Removing 8573 's Successors
# 1615 3012
# 1623 3012
# Removing contig-100_334.83153 's Successors
# 1625 3012
# Removing 4175 's Successors
# 1627 3012
# 1630 3012
# Removing 4285 's Successors
# 1631 3012
# 1640 3012
# 1645 3012
# 1652 3012
# 1653 3012
# 1662 3012
# 1671 3012
# 1675 3012
# 1690 3012
# 1693 3012
# 1696 3012
# Removing contig-100_688.80917 's Predecessors
# 1698 3012
# 1700 3012
# Removing contig-100_2366.79307 's Predecessors
# 1713 3012
# 1719 3012
# 1725 3012
# Removing 5341 's Predecessors
# 1726 3012
# Removing contig-100_9696.63449 's Successors
# 1729 3012
# 1744 3012
# Removing contig-100_762.83581 's Predecessors
# 1745 3012
# Removing contig-100_3517.35885 's Successors
# 1746 3012
# 1754 3012
# 300
# 1756 3012
# 1759 3012
# Removing 5705 's Predecessors
# 1761 3012
# 1776 3012
# 1779 3012
# 1780 3012
# 1785 3012
# Removing contig-100_169.80398 's Predecessors
# 1787 3012
# Removing contig-100_202.80431 's Successors
# 1789 3012
# Removing contig-100_2140.67475 's Successors
# 1797 3012
# 1800 3012
# 1811 3012
# 1818 3012
# Removing contig-100_5776.59529 's Predecessors
# 1821 3012
# 1828 3012
# 1829 3012
# 1835 3012
# 1855 3012
# Removing contig-100_9122.62875 's Successors
# 1863 3012
# 1866 3012
# 1873 3012
# 1874 3012
# 1884 3012
# 1886 3012
# 1895 3012
# 1904 3012
# 1907 3012
# Removing 769 's Successors
# 1910 3012
# 300
# 1914 3012
# 1915 3012
# 1933 3012
# Removing contig-100_583.80812 's Successors
# 1936 3012
# 1940 3012
# 1941 3012
# 1945 3012
# 1951 3012
# Removing 8763 's Predecessors
# 1958 3012
# 1968 3012
# 1971 3012
# Removing contig-100_6351.6351 's Successors
# 1973 3012
# 1977 3012
# 1985 3012
# Removing contig-100_2210.74553 's Predecessors
# 1987 3012
# Removing contig-100_8483.62236 's Successors
# 1996 3012
# 1999 3012
# 2006 3012
# 300
# Removing contig-100_10019.63772 's Predecessors
# 2007 3012
# 2008 3012
# 2009 3012
# 2015 3012
# 2029 3012
# 2040 3012
# 2045 3012
# 2046 3012
# 300
# Removing 9137 's Successors
# 2051 3012
# 2052 3012
# 2053 3012
# 2088 3012
# 2109 3012
# 2114 3012
# 2116 3012
# 2135 3012
# 300
# Removing contig-100_6442.71777 's Successors
# 2143 3012
# 2160 3012
# 2171 3012
# 300
# 2174 3012
# 2178 3012
# 2184 3012
# 300
# Removing contig-100_2724.79665 's Predecessors
# 2185 3012
# Removing contig-100_1043.83862 's Successors
# 2186 3012
# 300
# 2199 3012
# 300
# 2200 3012
# Removing contig-100_1554.84373 's Successors
# 2201 3012
# 2204 3012
# 300
# Removing contig-100_4288.69623 's Successors
# 2211 3012
# 300
# 2213 3012
# 2218 3012
# Removing contig-100_3389.68724 's Successors
# 2221 3012
# 2236 3012
# Removing contig-100_1173.83992 's Successors
# 2243 3012
# 2252 3012
# 300
# Removing contig-100_3061.75404 's Successors
# 2263 3012
# 2275 3012
# 2284 3012
# Removing contig-100_12871.45239 's Predecessors
# 2285 3012
# 2301 3012
# 2306 3012
# Removing contig-100_1449.66784 's Predecessors
# 2344 3012
# Removing contig-100_1542.73885 's Predecessors
# 2384 3012
# 2395 3012
# Removing contig-100_17782.50150 's Successors
# 2403 3012
# 2413 3012
# 300
# Removing contig-100_3451.35819 's Predecessors
# 2423 3012
# 300
# 2424 3012
# 2431 3012
# 2447 3012
# 2461 3012
# 2470 3012
# 2473 3012
# 2474 3012
# 2475 3012
# Removing contig-100_2697.79638 's Successors
# 2479 3012
# 2480 3012
# 2497 3012
# 300
# Removing contig-100_2274.82503 's Predecessors
# 2504 3012
# Removing contig-100_2065.79006 's Successors
# 2512 3012
# 2515 3012
# 300
# 2527 3012
# 2544 3012
# 2555 3012
# 300
# 2570 3012
# 300
# 2587 3012
# 2606 3012
# 300
# 2647 3012
# 300
# Removing contig-100_5100.37468 's Successors
# 2651 3012
# 2737 3012
# Removing contig-100_856.83675 's Successors
# 2756 3012
# 2777 3012
# 300
# Removing contig-100_5812.38180 's Successors
# 2778 3012
# 300
# 2790 3012
# SRS020622.txt

# %%
'''for s in samples[4:]:
    sample = s.replace(".txt","")
    if sample[0] == '.':
        continue
    print(s)
    Graph_path= graphspath+sample+'/'+sample+'_scaffolds/oriented.gml'
    G = nx.read_gml(Graph_path)
    df_coverage =Load_Read_Coverage(sample) 
    df_coords, df_coverage_scaffolds = Write_Coverage_Outputs(G, df_coverage)
    df_coords.to_csv(op_path+sample+'_Gbl_Coords.csv')
    df_coverage_scaffolds.to_csv(op_path+sample+'_Coverages.csv')'''
